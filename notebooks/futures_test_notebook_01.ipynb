# %%
# %load_ext zipline

# %%
# %matplotlib inline

# %%
# %%zipline --start 2018-1-1 --end 2018-10-10 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     #context.asset = future_symbol('CL')
#     context.cf = continuous_future('JY', roll='volume')
#
# def handle_data(context, data):
#     #contract = data.history(context.cf, 'contract', bar_count=100, frequency="1d")
#     #d = data.current('CLZ2018', ['price', 'volume'])
#
#     # Save values for later inspection
#     record(contract = data.current(context.cf, 'contract'),
#            volume = data.current(context.cf, 'volume'),
#            price = data.current(context.cf, 'price'))
# Out:
#                            algo_volatility  algorithm_period_return  alpha  \
# 2018-01-02 21:00:00+00:00              NaN                      0.0    NaN
# 2018-01-03 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-04 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-05 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-08 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-09 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-10 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-11 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-12 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-16 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-17 21:00:00+00:00              0.0                      0.0    0.0
# ...

# %%
x = _[['contract', 'volume', 'price']]
x
# Out:
#                           contract  volume  price
# 2018-01-02 21:00:00+00:00     None       0    NaN
# 2018-01-03 21:00:00+00:00     None       0    NaN
# 2018-01-04 21:00:00+00:00     None       0    NaN
# 2018-01-05 21:00:00+00:00     None       0    NaN
# 2018-01-08 21:00:00+00:00     None       0    NaN
# 2018-01-09 21:00:00+00:00     None       0    NaN
# 2018-01-10 21:00:00+00:00     None       0    NaN
# 2018-01-11 21:00:00+00:00     None       0    NaN
# 2018-01-12 21:00:00+00:00     None       0    NaN
# 2018-01-16 21:00:00+00:00     None       0    NaN
# 2018-01-17 21:00:00+00:00     None       0    NaN
# 2018-01-18 21:00:00+00:00     None       0    NaN
# 2018-01-19 21:00:00+00:00     None       0    NaN
# 2018-01-22 21:00:00+00:00     None       0    NaN
# 2018-01-23 21:00:00+00:00     None       0    NaN
# 2018-01-24 21:00:00+00:00     None       0    NaN
# 2018-01-25 21:00:00+00:00     None       0    NaN
# 2018-01-26 21:00:00+00:00     None       0    NaN
# ...

# %%
x['price'].plot();

# %%
x['volume'].plot();

# %%
# %%zipline --start 2018-1-1 --end 2018-10-9 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     #context.asset = future_symbol('CL')
#     context.cf = continuous_future('CL', roll='volume')
#
# def handle_data(context, data):
#     #contract = data.history(context.cf, 'contract', bar_count=100, frequency="1d")
#     d = data.current(future_symbol('CLZ2018'), ['price', 'volume'])
#
#     # Save values for later inspection
#     record(price=d['price'], volume=d['volume'])
# Out:
#                            algo_volatility  algorithm_period_return  alpha  \
# 2018-01-02 21:00:00+00:00              NaN                      0.0    NaN
# 2018-01-03 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-04 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-05 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-08 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-09 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-10 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-11 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-12 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-16 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-17 21:00:00+00:00              0.0                      0.0    0.0
# ...

# %%
d = _[['price', 'volume']]

# %%
d['volume'].plot();

# %%
# %%zipline --start 2018-1-1 --end 2018-10-20 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     context.cf = continuous_future('ES', roll='volume', adjustment='mul')
#
# def handle_data(context, data):
#     mav = data.history(context.cf, 'price', bar_count=50, frequency="1d").mean()
#     #d = data.current(context.cf, ['price', 'volume', 'contract'])
#     """
#     # Save values for later inspection
#     record(price=d['price'],
#            volume=d['volume'],
#            contract=d['contract']
#           )
#     """
#     record(price = data.current(context.cf, 'price'),
#           mav = mav)
# Out:
#                            algo_volatility  algorithm_period_return  alpha  \
# 2018-01-02 21:00:00+00:00              NaN                      0.0    NaN
# 2018-01-03 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-04 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-05 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-08 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-09 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-10 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-11 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-12 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-16 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-17 21:00:00+00:00              0.0                      0.0    0.0
# ...

# %%
r = _[['price', 'mav']]
r.head()
# Out:
#                              price        mav
# 2018-01-02 21:00:00+00:00  2694.00  2621.6342
# 2018-01-03 21:00:00+00:00  2709.25  2624.2910
# 2018-01-04 21:00:00+00:00  2725.00  2627.4680
# 2018-01-05 21:00:00+00:00  2742.50  2630.9600
# 2018-01-08 21:00:00+00:00  2747.00  2634.6520

# %%
r.tail()
# Out:
#                              price        mav
# 2018-10-15 20:00:00+00:00  2747.00  2880.8344
# 2018-10-16 20:00:00+00:00  2816.50  2880.0814
# 2018-10-17 20:00:00+00:00  2816.25  2879.0880
# 2018-10-18 20:00:00+00:00  2775.25  2877.4198
# 2018-10-19 20:00:00+00:00  2767.50  2875.6218

# %%
r.plot();

# %%
# %%zipline --start 2018-1-1 --end 2018-10-20 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     context.cf = continuous_future('ES', roll='volume', adjustment='mul')
#     context.i = 0
#
# def handle_data(context, data):
#
#
#     d = data.history(context.cf, ['open', 'high', 'low', 'close'], bar_count=50, frequency="1d")
#     #d = data.current(context.cf, ['price', 'volume', 'contract'])
#     """
#     # Save values for later inspection
#     record(price=d['price'],
#            volume=d['volume'],
#            contract=d['contract']
#           )
#     """
#     print(d.iloc[-1:])
# Out:
#                             close    high     low     open
# 2018-01-02 00:00:00+00:00  2694.0  2696.0  2674.5  2675.25
#                              close     high      low     open
# 2018-01-03 00:00:00+00:00  2709.25  2714.25  2692.25  2693.75
#                             close    high     low     open
# 2018-01-04 00:00:00+00:00  2725.0  2729.0  2708.5  2710.25
#                             close     high      low    open
# 2018-01-05 00:00:00+00:00  2742.5  2743.25  2723.75  2725.0
#                             close    high     low     open
# 2018-01-08 00:00:00+00:00  2747.0  2748.5  2736.5  2741.75
#                              close    high      low    open
# 2018-01-09 00:00:00+00:00  2750.25  2760.0  2742.75  2746.5
#                              close    high     low     open
# 2018-01-10 00:00:00+00:00  2750.75  2752.0  2736.5  2749.75
#                              close    high      low    open
# 2018-01-11 00:00:00+00:00  2769.25  2770.5  2747.75  2750.0
# ...

# %%
# %%zipline --start 2018-1-1 --end 2018-10-20 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     context.es = continuous_future('ES', roll='volume', adjustment='mul')
#     context.cl = continuous_future('CL', roll='volume', adjustment='mul')
#
# def handle_data(context, data):
#     context.d = data.history([context.es, context.cl], ['open', 'high', 'low', 'close'], bar_count=50, frequency="1d")
#     #d = data.current(context.cf, ['price', 'volume', 'contract'])
#     """
#     # Save values for later inspection
#     record(price=d['price'],
#            volume=d['volume'],
#            contract=d['contract']
#           )
#     """
# def analyze(context, data):
#     print(context.d['open'].head())
#     print(context.d['high'].head())
#     print(context.d['low'].head())
#     print(context.d['close'].head())
# Out:
#                            ContinuousFuture(91570626912911360 [ES, 0, volume, mul])  \
# 2018-08-10 00:00:00+00:00                                            2857.65
# 2018-08-13 00:00:00+00:00                                            2840.87
# 2018-08-14 00:00:00+00:00                                            2831.86
# 2018-08-15 00:00:00+00:00                                            2846.88
# 2018-08-16 00:00:00+00:00                                            2827.35
#
#                            ContinuousFuture(90999980378095616 [CL, 0, volume, mul])
# 2018-08-10 00:00:00+00:00                                              65.78
# 2018-08-13 00:00:00+00:00                                              66.81
# 2018-08-14 00:00:00+00:00                                              66.45
# 2018-08-15 00:00:00+00:00                                              65.67
# 2018-08-16 00:00:00+00:00                                              64.02
# ...

# %% [markdown]
# Why the fuck doesn't this work?

# %%
# %%zipline --start 2018-1-1 --end 2018-10-20 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     context.cf = continuous_future('ES', roll='volume', adjustment='add')
#
#
# def handle_data(context, data):
#     d = data.current(context.cf, ['price', 'volume'])
#
#     #record(price=d['price'], volume=d['volume'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-65c1bac84510> in <module>()
# ----> 1 get_ipython().run_cell_magic('zipline', '--start 2018-1-1 --end 2018-10-20 -b futures', "from zipline.api import order_target, record, symbol, continuous_future, future_symbol\n\ndef initialize(context):\n    context.cf = continuous_future('ES', roll='volume', adjustment='add')\n\n    \ndef handle_data(context, data):\n    d = data.current(context.cf, ['price', 'volume'])\n\n    #record(price=d['price'], volume=d['volume'])")
#
# C:\Program Files\Python36\Lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# ...

# %%
# %%zipline --start 2018-1-1 --end 2018-10-20 -b futures
# from zipline.api import order_target, record, symbol, continuous_future, future_symbol
#
# def initialize(context):
#     context.cf = continuous_future('ES', roll='volume', adjustment='add')
#
#
# def handle_data(context, data):
#     d = data.current_chain(context.cf)
#
#     record(chain=d)
# Out:
#                            algo_volatility  algorithm_period_return  alpha  \
# 2018-01-02 21:00:00+00:00              NaN                      0.0    NaN
# 2018-01-03 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-04 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-05 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-08 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-09 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-10 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-11 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-12 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-16 21:00:00+00:00              0.0                      0.0    0.0
# 2018-01-17 21:00:00+00:00              0.0                      0.0    0.0
# ...

# %%
ch = _['chain']

# %%
ch.head()
# Out:
# 2018-01-02 21:00:00+00:00    [Future(25713 [ESH2018]), Future(26362 [ESM201...
# 2018-01-03 21:00:00+00:00    [Future(25713 [ESH2018]), Future(26362 [ESM201...
# 2018-01-04 21:00:00+00:00    [Future(25713 [ESH2018]), Future(26362 [ESM201...
# 2018-01-05 21:00:00+00:00    [Future(25713 [ESH2018]), Future(26362 [ESM201...
# 2018-01-08 21:00:00+00:00    [Future(25713 [ESH2018]), Future(26362 [ESM201...
# Name: chain, dtype: object

# %%
ch[-1]
# Out:
# [Future(27671 [ESZ2018]),
#  Future(28265 [ESH2019]),
#  Future(28833 [ESM2019]),
#  Future(29380 [ESU2019]),
#  Future(29906 [ESZ2019])]

# %%
# %%zipline --start 2018-1-1 --end 2018-10-20 -b futures
# from zipline.api import (order, record, symbol, continuous_future, future_symbol,
#                          order_target_percent, set_slippage, set_commission)
# from zipline.finance.slippage import FixedSlippage
# from zipline.finance.commission import PerTrade
# import random
#
# def initialize(context):
#     context.cf = continuous_future('ES', roll='volume', adjustment='add')
#     context.counter = 0
#     set_slippage(us_futures=FixedSlippage(spread=0.0))
#     set_commission(us_futures=PerTrade(0))
#
# def handle_data(context, data):
#     """
#     If there are no open positions, randomly buy or sell one contract. Hold for 10 days. Close-out.
#     """
#     if context.portfolio.positions:
#         context.counter += 1
#         positions = context.portfolio.positions
#         asset_object = list(positions.keys())[0]
#         position_object = positions[asset_object]
#         record(cost = position_object.cost_basis,
#                amount = position_object.amount)
#         if context.counter < 10:
#             return
#         else:
#             order(asset_object, -position_object.amount)
#             context.counter = 0
#     else:
#         asset = data.current(context.cf, 'contract')
#         open = data.current(context.cf, 'open')
#         amount = random.sample([-1, 1], 1)[0]
#         order(asset, amount, limit_price=open)
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2018-01-02 21:00:00+00:00              NaN                 0.000000       NaN
# 2018-01-03 21:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-01-04 21:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-01-05 21:00:00+00:00         0.000744                -0.000094  0.010470
# 2018-01-08 21:00:00+00:00         0.000645                -0.000115 -0.001667
# 2018-01-09 21:00:00+00:00         0.000577                -0.000142 -0.003765
# 2018-01-10 21:00:00+00:00         0.000562                -0.000134 -0.001223
# 2018-01-11 21:00:00+00:00         0.000672                -0.000229 -0.000322
# 2018-01-12 21:00:00+00:00         0.000724                -0.000325 -0.000211
# 2018-01-16 21:00:00+00:00         0.000762                -0.000294  0.000204
# 2018-01-17 21:00:00+00:00         0.000811                -0.000400  0.000559
# ...

# %%
results = _

# %%
results.head()
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2018-01-02 21:00:00+00:00              NaN                 0.000000       NaN
# 2018-01-03 21:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-01-04 21:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-01-05 21:00:00+00:00         0.000744                -0.000094  0.010470
# 2018-01-08 21:00:00+00:00         0.000645                -0.000115 -0.001667
#
#                            amount  benchmark_period_return  \
# 2018-01-02 21:00:00+00:00     NaN                 0.007157
# 2018-01-03 21:00:00+00:00     NaN                 0.013528
# 2018-01-04 21:00:00+00:00    -1.0                 0.017800
# 2018-01-05 21:00:00+00:00    -1.0                 0.024582
# 2018-01-08 21:00:00+00:00    -1.0                 0.026456
#
#                            benchmark_volatility      beta  capital_used  \
# ...

# %%
results['transactions'][2]
# Out:
# [{'amount': -1,
#   'commission': None,
#   'dt': Timestamp('2018-01-04 21:00:00+0000', tz='UTC'),
#   'order_id': 'd4e789b22a544e9ca2028553c11ad13c',
#   'price': 2723.75,
#   'sid': Future(25708 [ESH18])}]

# %%
results[['amount', 'cost']].head()
# Out:
#                            amount     cost
# 2018-01-02 21:00:00+00:00     NaN      NaN
# 2018-01-03 21:00:00+00:00     NaN      NaN
# 2018-01-04 21:00:00+00:00    -1.0  2723.75
# 2018-01-05 21:00:00+00:00    -1.0  2723.75
# 2018-01-08 21:00:00+00:00    -1.0  2723.75

# %%
results["2018-1-3"].to_dict()
# Out:
# {'algo_volatility': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): 0.0003390278900924656},
#  'algorithm_period_return': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): -3.0203004983020421e-05},
#  'alpha': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): -0.06548460244352669},
#  'amount': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): -1.0},
#  'benchmark_period_return': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): 0.013527657214313926},
#  'benchmark_volatility': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): 0.0093375997472393019},
#  'beta': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): 0.036307819918357492},
#  'capital_used': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): -302.03004983098731},
#  'cost': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): 2703.2093990033804},
#  'ending_cash': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): 9999697.9699501693},
#  'ending_exposure': {Timestamp('2018-01-03 21:00:00+0000', tz='UTC'): -135462.5},
# ...

# %%
results['2018-10-19'].to_dict()
# Out:
# {'algo_volatility': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 0.0017372461164454813},
#  'algorithm_period_return': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): -0.00047979226974781408},
#  'alpha': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): -0.00055647655334315729},
#  'amount': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 1.0},
#  'benchmark_period_return': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 0.048721812160919642},
#  'benchmark_volatility': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 0.14641209665774577},
#  'beta': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): -0.00054110375656510432},
#  'capital_used': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): -387.5},
#  'cost': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 2785.6656018339513},
#  'ending_cash': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 9995202.0773025081},
#  'ending_exposure': {Timestamp('2018-10-19 20:00:00+0000', tz='UTC'): 138375.0},
# ...
