# %%
import os
import pandas as pd
from zipline.data import bundles
from zipline.data.data_portal import DataPortal
from zipline.utils.calendars import get_calendar
from zipline.assets._assets import Future
from zipline.utils.run_algo import load_extensions

# Load extensions.py; this allows you access to custom bundles
load_extensions(
    default=True,
    extensions=[],
    strict=True,
    environ=os.environ,
)

# Set-Up Pricing Data Access
trading_calendar = get_calendar('us_futures')
bundle = 'futures'
bundle_data = bundles.load(bundle)

data = DataPortal(
    bundle_data.asset_finder,
    trading_calendar=trading_calendar,
    first_trading_day=bundle_data.equity_daily_bar_reader.first_trading_day,
    equity_minute_reader=None,
    equity_daily_reader=bundle_data.equity_daily_bar_reader,
    future_daily_reader=bundle_data.equity_daily_bar_reader,
    adjustment_reader=bundle_data.adjustment_reader,
)

# %%
future = bundle_data.asset_finder.lookup_future_symbol
continuous_future = bundle_data.asset_finder.create_continuous_future
history = data.get_history_window

# %%
contracts = [
    # rates
    'ED', # eurodollars
    'TY', # 10y T-note
    'FV', # 5y T-note
    'TU', # 2y T-note
    'US', # U.S. Treasury bond
    'FF', # 30 day Fed funds
    'UL', # Ultra T-bond
    'SA', # 5y deliverable IRS
    'N1U',# 10y deliverable IRS
    'I3', # 30y deliverable IRS
    # equity
    'ES', # e-mini S&P 500
    'NQ', # e-mini Nasdaq 100
    'YM', # e-mini DowJones
    'MD', # e-mini S&P MidCap 400
    'NK', # Nikkei $5
    'XAF',# e-mini financial sector
    'XAK',# e-mini technology sector
    'XAP',# e-mini consumer staples sector
    'XAU',# e-mini utilities sector
    'XAY',# e-mini consumer discretionary sector
    # energy
    'CL', # WTI oil
    'NG', # natural gas
    'RB', # RBOB gasoline
    'HO', # NY Harbor ULSD
    'BZ', # Brent oil
    # fx
    'EC', # EUR/USD
    #'JY', # JPY/USD
    #'BP', # GBP/USD
    #'AD', # AUD/USD
    #'CD', # CAD/USD
    #'MP', # MXN/USD
    #'SF', # CHF/USD
    # agriculture
    '_C', # Corn
    '_S', # Soybeans
    '_W', # Chicago SRW Wheat
    'BO', # Soybean oil
    'SM', # Soybean meal
    'LC', # Live cattle
    'KW', # KC HRW wheat
    'LN', # Lean hogs
    # metals
    #'GC', # Gold
    'HG', # Copper
    'SI', # Silver
    #'PL', # Platinum
    #'PA', # Palladium
    ]

# %%
cont_contracts = [
    continuous_future(contract,
                        offset=0,
                        adjustment='mul',
                        roll_style='volume')
    for contract in contracts]

# %%
cont_contracts
# Out:
# [ContinuousFuture(91554134238494720, root_symbol='ED', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95799348633337856, root_symbol='TY', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91855400424505344, root_symbol='FV', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95794950586826752, root_symbol='TU', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96074226540281856, root_symbol='US', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91837808238460928, root_symbol='FF', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96066529958887424, root_symbol='UL', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95491485377560576, root_symbol='SA', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94066518307962880, root_symbol='N1U', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92661342447665152, root_symbol='I3', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91570626912911360, root_symbol='ES', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94101702680051712, root_symbol='NQ', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(97193529377357824, root_symbol='YM', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93805934052179968, root_symbol='MD', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94095105610285056, root_symbol='NK', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAF', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAK', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAP', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAU', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAY', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90999980378095616, root_symbol='CL', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94090707563773952, root_symbol='NG', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95211109912477696, root_symbol='RB', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92410653796532224, root_symbol='HO', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90733898564173824, root_symbol='BZ', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91553034726866944, root_symbol='EC', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(98871384121344000, root_symbol='_C', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(98888976307388416, root_symbol='_S', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(98893374353899520, root_symbol='_W', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90721803936268288, root_symbol='BO', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95504679517093888, root_symbol='SM', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93523359563841536, root_symbol='LC', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93263874819686400, root_symbol='KW', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93535454191747072, root_symbol='LN', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92401857703510016, root_symbol='HG', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95500281470582784, root_symbol='SI', offset=0, roll_style='volume', adjustment='mul')]

# %%
[(c.root_symbol, c.start_date) for c in cont_contracts]
# Out:
# [('ED', Timestamp('1982-02-01 00:00:00+0000', tz='UTC')),
#  ('TY', Timestamp('1982-05-03 00:00:00+0000', tz='UTC')),
#  ('FV', Timestamp('1988-05-20 00:00:00+0000', tz='UTC')),
#  ('TU', Timestamp('1990-06-22 00:00:00+0000', tz='UTC')),
#  ('US', Timestamp('1977-08-22 00:00:00+0000', tz='UTC')),
#  ('FF', Timestamp('1988-10-03 00:00:00+0000', tz='UTC')),
#  ('UL', Timestamp('2012-10-30 00:00:00+0000', tz='UTC')),
#  ('SA', Timestamp('2012-10-30 00:00:00+0000', tz='UTC')),
#  ('N1U', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('I3', Timestamp('2012-10-30 00:00:00+0000', tz='UTC')),
#  ('ES', Timestamp('1997-09-09 00:00:00+0000', tz='UTC')),
#  ('NQ', Timestamp('1999-06-21 00:00:00+0000', tz='UTC')),
#  ('YM', Timestamp('1997-10-06 00:00:00+0000', tz='UTC')),
#  ('MD', Timestamp('1992-02-13 00:00:00+0000', tz='UTC')),
#  ('NK', Timestamp('1990-09-25 00:00:00+0000', tz='UTC')),
#  ('XAF', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAK', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAP', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAU', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAY', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('CL', Timestamp('1983-03-30 00:00:00+0000', tz='UTC')),
#  ('NG', Timestamp('1990-04-03 00:00:00+0000', tz='UTC')),
#  ('RB', Timestamp('2005-10-03 00:00:00+0000', tz='UTC')),
#  ('HO', Timestamp('1979-03-06 00:00:00+0000', tz='UTC')),
#  ('BZ', Timestamp('2011-10-03 00:00:00+0000', tz='UTC')),
#  ('EC', Timestamp('1999-01-04 00:00:00+0000', tz='UTC')),
#  ('_C', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('_S', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('_W', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('BO', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('SM', Timestamp('1959-07-02 00:00:00+0000', tz='UTC')),
#  ('LC', Timestamp('1964-11-30 00:00:00+0000', tz='UTC')),
#  ('KW', Timestamp('1976-04-09 00:00:00+0000', tz='UTC')),
#  ('LN', Timestamp('1969-06-25 00:00:00+0000', tz='UTC')),
#  ('HG', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('SI', Timestamp('1963-06-13 00:00:00+0000', tz='UTC'))]

# %%
h = history(
    assets=cont_contracts,
    end_dt=pd.Timestamp('2018-10-31'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-26d2252754f7> in <module>()
#       1 h = history(
# ----> 2     assets=cont_contracts,
#       3     end_dt=pd.Timestamp('2018-10-31'),
#       4     bar_count=100,
#       5     frequency='1d',
#
# NameError: name 'cont_contracts' is not defined

# %%
h.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-da8b60ec2fad> in <module>()
# ----> 1 h.head()
#
# NameError: name 'h' is not defined

# %%
for c in cont_contracts:
    his = history(
        assets=[c],
        end_dt=pd.Timestamp('2017-1-1'),
        bar_count=100,
        frequency='1d',
        field='price',
        data_frequency='daily'
        )
    print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f74fe7364bb6> in <module>()
# ----> 1 for c in cont_contracts:
#       2     his = history(
#       3         assets=[c],
#       4         end_dt=pd.Timestamp('2017-1-1'),
#       5         bar_count=100,
#
# NameError: name 'cont_contracts' is not defined

# %%
a = pd.read_csv('C:/Users/tomek/zipline/debug/CMEGroup.csv', header=None)

# %%
a.head()
# Out:
#      0    1                           2             3        4
# 0  IBV  CME            Ibovespa Futures        GJMQVZ  CME/IBV
# 1   EM  CME  1-month Eurodollar Futures  FGHJKMNQUVXZ   CME/EM
# 2   EY  CME             EuroYen Futures          HMUZ   CME/EY
# 3   ED  CME          Eurodollar Futures      HJKMNQUZ   CME/ED
# 4  CPO  CME      Crude Palm Oil Futures      FHKMNQUX  CME/CPO

# %%
all_roots = a[0]

# %%
all_roots = all_roots.tolist()

# %%
all_roots
# Out:
# ['IBV',
#  'EM',
#  'EY',
#  'ED',
#  'CPO',
#  'ES',
#  'NN',
#  'TY',
#  'FV',
#  'N9',
#  'CL',
#  'C',
#  'NG',
#  'V3',
#  'NP',
#  'B6',
#  'TU',
#  'E4',
#  'K4',
#  'US',
#  'D2',
#  'S',
#  'L3',
#  'UL',
#  'HH',
#  'NQ',
#  'W',
#  'GC',
#  'H4',
#  'O1',
#  'BO',
#  'H2',
#  'LC',
#  'D4',
#  'HO',
#  'I6',
#  'FF',
#  'SM',
#  'LN',
#  'RB',
#  'EC',
#  'JY',
#  'BP',
#  'K2',
#  'X1',
#  'OFM',
#  'CD',
#  'HG',
#  'KW',
#  'CS',
#  'SP',
#  'SI',
#  'W6',
#  'YM',
#  'D9',
#  '6T',
#  'MP',
#  'F5',
#  'AD',
#  'FTM',
#  'N1Y',
#  'L1',
#  'MD',
#  'HMO',
#  'BK',
#  'R7',
#  'NK',
#  '4M',
#  'MTF',
#  'U5',
#  'P8',
#  'HP',
#  'LT',
#  'BZ',
#  'A3',
#  'L9',
#  'PL',
#  'Z9',
#  'B3',
#  'R3',
#  'T3',
#  'N1U',
#  '46',
#  'K3',
#  'FC',
#  'J4',
#  'WJ',
#  'ME',
#  'W4',
#  'SF',
#  'CY',
#  'RU',
#  'PA',
#  'MF',
#  'H3',
#  'CU',
#  'SA',
#  'MFF',
#  'HK',
#  'WS',
#  'U6',
#  '7K',
#  'GZ',
#  'DA',
#  'GCU',
#  'FO',
#  'GA',
#  'FDM',
#  'F2',
#  'PH',
#  '4P',
#  'N3',
#  'PG',
#  'GY',
#  'NE',
#  'D3',
#  'NL',
#  'JM',
#  'OPM',
#  'PD',
#  'BB',
#  'B0',
#  'I5',
#  'WCC',
#  'GL',
#  'RBB',
#  'N1',
#  'RP',
#  '58',
#  'HA',
#  'H5',
#  'NEN',
#  'AGA',
#  'RV',
#  'D0',
#  'RM',
#  'JP',
#  'A6',
#  'QP',
#  'MPX',
#  'HB',
#  '1N',
#  'BR',
#  'EN',
#  'KA',
#  'RY',
#  'ND',
#  'RL',
#  'HR',
#  'O',
#  'NR',
#  'YX',
#  'SG',
#  'GI',
#  'E8',
#  'RF',
#  'DJ',
#  'AFF',
#  'U3',
#  'DK',
#  'Y1',
#  'D7',
#  'ABY',
#  '5Z',
#  'UV',
#  'TZ6',
#  'NX',
#  'YC',
#  'L5',
#  'QX',
#  '0D',
#  'RK',
#  'PTM',
#  'YK',
#  'CSC',
#  'CZ',
#  'FY',
#  'MM',
#  'CI',
#  'KJ',
#  'C0',
#  'AW',
#  'L6',
#  'KS',
#  'LY',
#  'RR',
#  'D8',
#  'VP',
#  'UX',
#  'VM',
#  'NKN',
#  'KG',
#  'NI',
#  'MEO',
#  'UB',
#  'E5',
#  'RA',
#  'TR',
#  'HMW',
#  'VR',
#  'IN',
#  'MTS',
#  'NS',
#  'B4',
#  'I3',
#  'CB',
#  'E3',
#  'E7',
#  'KI',
#  'QM',
#  '7H',
#  'UO',
#  'FH',
#  'HOB',
#  'UA',
#  'D6',
#  'P5',
#  'M6E',
#  'SE',
#  'TC',
#  'KB',
#  '7Q',
#  '4L',
#  'FI',
#  'MG',
#  'TIO',
#  '1NB',
#  'JR',
#  'YH',
#  'XN',
#  'MOD',
#  'U4',
#  'A5',
#  'LB',
#  'NF',
#  'Q5',
#  'DC',
#  'EH',
#  'Z',
#  'MEL',
#  'P7',
#  'R6',
#  'NW',
#  'FS',
#  'QL',
#  'UM',
#  'DB',
#  '0F',
#  'QG',
#  'J2',
#  'L4',
#  'MNC',
#  'KH',
#  '47',
#  'EW',
#  'NYF',
#  'NZ',
#  'SZ',
#  'NH',
#  'EJ',
#  'NJ',
#  'NFN',
#  'XAU',
#  'Y7',
#  '9F',
#  'Z1',
#  'GE',
#  'S4',
#  'DY',
#  'SSI',
#  'YW',
#  '1R',
#  'MJN',
#  'MBE',
#  'XAP',
#  'MNB',
#  '5C',
#  'XAK',
#  'SD',
#  '7Y',
#  'PF',
#  '8Z',
#  'MBN',
#  'BY',
#  '1U',
#  'PZ',
#  '6Z',
#  'MGC',
#  'BOB',
#  'TRY',
#  'UN',
#  'PDM',
#  '71',
#  '4N',
#  'GCI',
#  'XAF',
#  'CNH',
#  'ARW',
#  'KK',
#  'JS',
#  'XAY',
#  'MCC',
#  'FP',
#  'WQ',
#  'PC',
#  'J7',
#  'M6B',
#  '8I']

# %%
roots=[]
for r in all_roots:
    if len(r) == 1:
        r = '_' + r
    roots.append(r)

# %%
roots
# Out:
# ['IBV',
#  'EM',
#  'EY',
#  'ED',
#  'CPO',
#  'ES',
#  'NN',
#  'TY',
#  'FV',
#  'N9',
#  'CL',
#  '_C',
#  'NG',
#  'V3',
#  'NP',
#  'B6',
#  'TU',
#  'E4',
#  'K4',
#  'US',
#  'D2',
#  '_S',
#  'L3',
#  'UL',
#  'HH',
#  'NQ',
#  '_W',
#  'GC',
#  'H4',
#  'O1',
#  'BO',
#  'H2',
#  'LC',
#  'D4',
#  'HO',
#  'I6',
#  'FF',
#  'SM',
#  'LN',
#  'RB',
#  'EC',
#  'JY',
#  'BP',
#  'K2',
#  'X1',
#  'OFM',
#  'CD',
#  'HG',
#  'KW',
#  'CS',
#  'SP',
#  'SI',
#  'W6',
#  'YM',
#  'D9',
#  '6T',
#  'MP',
#  'F5',
#  'AD',
#  'FTM',
#  'N1Y',
#  'L1',
#  'MD',
#  'HMO',
#  'BK',
#  'R7',
#  'NK',
#  '4M',
#  'MTF',
#  'U5',
#  'P8',
#  'HP',
#  'LT',
#  'BZ',
#  'A3',
#  'L9',
#  'PL',
#  'Z9',
#  'B3',
#  'R3',
#  'T3',
#  'N1U',
#  '46',
#  'K3',
#  'FC',
#  'J4',
#  'WJ',
#  'ME',
#  'W4',
#  'SF',
#  'CY',
#  'RU',
#  'PA',
#  'MF',
#  'H3',
#  'CU',
#  'SA',
#  'MFF',
#  'HK',
#  'WS',
#  'U6',
#  '7K',
#  'GZ',
#  'DA',
#  'GCU',
#  'FO',
#  'GA',
#  'FDM',
#  'F2',
#  'PH',
#  '4P',
#  'N3',
#  'PG',
#  'GY',
#  'NE',
#  'D3',
#  'NL',
#  'JM',
#  'OPM',
#  'PD',
#  'BB',
#  'B0',
#  'I5',
#  'WCC',
#  'GL',
#  'RBB',
#  'N1',
#  'RP',
#  '58',
#  'HA',
#  'H5',
#  'NEN',
#  'AGA',
#  'RV',
#  'D0',
#  'RM',
#  'JP',
#  'A6',
#  'QP',
#  'MPX',
#  'HB',
#  '1N',
#  'BR',
#  'EN',
#  'KA',
#  'RY',
#  'ND',
#  'RL',
#  'HR',
#  '_O',
#  'NR',
#  'YX',
#  'SG',
#  'GI',
#  'E8',
#  'RF',
#  'DJ',
#  'AFF',
#  'U3',
#  'DK',
#  'Y1',
#  'D7',
#  'ABY',
#  '5Z',
#  'UV',
#  'TZ6',
#  'NX',
#  'YC',
#  'L5',
#  'QX',
#  '0D',
#  'RK',
#  'PTM',
#  'YK',
#  'CSC',
#  'CZ',
#  'FY',
#  'MM',
#  'CI',
#  'KJ',
#  'C0',
#  'AW',
#  'L6',
#  'KS',
#  'LY',
#  'RR',
#  'D8',
#  'VP',
#  'UX',
#  'VM',
#  'NKN',
#  'KG',
#  'NI',
#  'MEO',
#  'UB',
#  'E5',
#  'RA',
#  'TR',
#  'HMW',
#  'VR',
#  'IN',
#  'MTS',
#  'NS',
#  'B4',
#  'I3',
#  'CB',
#  'E3',
#  'E7',
#  'KI',
#  'QM',
#  '7H',
#  'UO',
#  'FH',
#  'HOB',
#  'UA',
#  'D6',
#  'P5',
#  'M6E',
#  'SE',
#  'TC',
#  'KB',
#  '7Q',
#  '4L',
#  'FI',
#  'MG',
#  'TIO',
#  '1NB',
#  'JR',
#  'YH',
#  'XN',
#  'MOD',
#  'U4',
#  'A5',
#  'LB',
#  'NF',
#  'Q5',
#  'DC',
#  'EH',
#  '_Z',
#  'MEL',
#  'P7',
#  'R6',
#  'NW',
#  'FS',
#  'QL',
#  'UM',
#  'DB',
#  '0F',
#  'QG',
#  'J2',
#  'L4',
#  'MNC',
#  'KH',
#  '47',
#  'EW',
#  'NYF',
#  'NZ',
#  'SZ',
#  'NH',
#  'EJ',
#  'NJ',
#  'NFN',
#  'XAU',
#  'Y7',
#  '9F',
#  'Z1',
#  'GE',
#  'S4',
#  'DY',
#  'SSI',
#  'YW',
#  '1R',
#  'MJN',
#  'MBE',
#  'XAP',
#  'MNB',
#  '5C',
#  'XAK',
#  'SD',
#  '7Y',
#  'PF',
#  '8Z',
#  'MBN',
#  'BY',
#  '1U',
#  'PZ',
#  '6Z',
#  'MGC',
#  'BOB',
#  'TRY',
#  'UN',
#  'PDM',
#  '71',
#  '4N',
#  'GCI',
#  'XAF',
#  'CNH',
#  'ARW',
#  'KK',
#  'JS',
#  'XAY',
#  'MCC',
#  'FP',
#  'WQ',
#  'PC',
#  'J7',
#  'M6B',
#  '8I']

# %%
len(roots)
# Out:
# 308

# %%
names = {x: a[a[0]==x][2].item() for x in f}

# %%
names
# Out:
# {'6Z': 'Tennessee 800 Leg Natural Gas (Platts IFERC) Basis Futures',
#  '9F': 'Texas Gas Zone 1 Natural Gas (Platts IFERC) Basis Futures',
#  'AD': 'Australian Dollar Futures',
#  'BP': 'British Pound Futures',
#  'CD': 'Canadian Dollar Futures',
#  'CZ': 'Transco Zone 3 Natural Gas (Platts IFERC) Basis Futures',
#  'GC': 'Gold Futures',
#  'GL': 'Columbia Gulf Louisiana Natural Gas (Platts IFERC) Basis Futures',
#  'HB': 'Henry Hub Natural Gas (Platts IFERC) Basis Futures',
#  'JY': 'Japanese Yen Futures',
#  'L9': 'ISO New England West Central Massachusetts Zone 5 MW Off-Peak Calendar-Month Day Ahead LMP Futures',
#  'ME': 'Gulf Coast Jet (Platts) Up-Down Futures',
#  'NZ': 'Transco Zone 6 Natural Gas (Platts IFERC) Basis Futures',
#  'PA': 'Palladium Futures',
#  'PL': 'Platinum Futures',
#  'SZ': 'Southern Natural Louisiana Natural Gas (Platts IFERC) Basis Futures',
#  'TZ6': 'Transco Zone 6 Non-N.Y. Natural Gas (Platts IFERC) Basis Futures',
#  'WQ': 'Gasoil 0.1 Barges FOB Rdam (Platts) vs. Gasoil Futures'}

# %%
future('JYH1977').start_date
# Out:
# Timestamp('1976-08-02 00:00:00+0000', tz='UTC')

# %%
a = continuous_future('GC',
                  offset=0,
                  adjustment='mul',
                  roll_style='volume')

# %%
a
# Out:
# ContinuousFuture(92115984680288256, root_symbol='GC', offset=0, roll_style='volume', adjustment='mul')

# %%
a.start_date
# Out:
# Timestamp('2262-04-11 23:47:16.854775807+0000', tz='UTC')

# %%
a.end_date
# Out:
# Timestamp('1970-01-01 00:00:00+0000', tz='UTC')

# %%
a.to_dict()
# Out:
# {'end_date': Timestamp('1970-01-01 00:00:00+0000', tz='UTC'),
#  'exchange': 'CEC',
#  'offset': 0,
#  'roll_style': 'volume',
#  'root_symbol': 'GC',
#  'sid': 92115984680288256,
#  'start_date': Timestamp('2262-04-11 23:47:16.854775807+0000', tz='UTC')}

# %%
jy_contracts = []
for x in ['{}{}{}'.format('JY', l, y)  for y in range(1978, 2023) for l in 'FGHJKMNQUVXZ']:
    try:
        jy_contracts.append(bundle_data.asset_finder.lookup_future_symbol(x))
    except:
        pass

# %%
jy_contracts
# Out:
# [Future(25 [JYH1978]),
#  Future(27 [JYM1978]),
#  Future(30 [JYU1978]),
#  Future(32 [JYZ1978]),
#  Future(35 [JYH1979]),
#  Future(37 [JYM1979]),
#  Future(40 [JYU1979]),
#  Future(42 [JYZ1979]),
#  Future(45 [JYH1980]),
#  Future(47 [JYM1980]),
#  Future(50 [JYU1980]),
#  Future(51 [JYZ1980]),
#  Future(54 [JYH1981]),
#  Future(56 [JYM1981]),
#  Future(59 [JYU1981]),
#  Future(61 [JYZ1981]),
#  Future(64 [JYH1982]),
#  Future(66 [JYM1982]),
#  Future(69 [JYU1982]),
#  Future(71 [JYZ1982]),
#  Future(74 [JYH1983]),
#  Future(77 [JYM1983]),
#  Future(84 [JYU1983]),
#  Future(89 [JYZ1983]),
#  Future(95 [JYH1984]),
#  Future(99 [JYM1984]),
#  Future(105 [JYU1984]),
#  Future(111 [JYZ1984]),
#  Future(116 [JYH1985]),
#  Future(121 [JYM1985]),
#  Future(127 [JYU1985]),
#  Future(132 [JYZ1985]),
#  Future(138 [JYH1986]),
#  Future(143 [JYM1986]),
#  Future(149 [JYU1986]),
#  Future(154 [JYZ1986]),
#  Future(160 [JYH1987]),
#  Future(165 [JYM1987]),
#  Future(171 [JYU1987]),
#  Future(176 [JYZ1987]),
#  Future(182 [JYH1988]),
#  Future(187 [JYM1988]),
#  Future(193 [JYU1988]),
#  Future(198 [JYZ1988]),
#  Future(204 [JYH1989]),
#  Future(209 [JYM1989]),
#  Future(215 [JYU1989]),
#  Future(220 [JYZ1989]),
#  Future(226 [JYH1990]),
#  Future(231 [JYM1990]),
#  Future(237 [JYU1990]),
#  Future(242 [JYZ1990]),
#  Future(248 [JYH1991]),
#  Future(253 [JYM1991]),
#  Future(259 [JYU1991]),
#  Future(264 [JYZ1991]),
#  Future(270 [JYH1992]),
#  Future(275 [JYM1992]),
#  Future(281 [JYU1992]),
#  Future(286 [JYZ1992]),
#  Future(292 [JYH1993]),
#  Future(297 [JYM1993]),
#  Future(303 [JYU1993]),
#  Future(308 [JYZ1993]),
#  Future(314 [JYH1994]),
#  Future(319 [JYM1994]),
#  Future(325 [JYU1994]),
#  Future(330 [JYZ1994]),
#  Future(337 [JYH1995]),
#  Future(344 [JYM1995]),
#  Future(351 [JYU1995]),
#  Future(358 [JYZ1995]),
#  Future(365 [JYH1996]),
#  Future(372 [JYM1996]),
#  Future(379 [JYU1996]),
#  Future(386 [JYZ1996]),
#  Future(393 [JYH1997]),
#  Future(400 [JYM1997]),
#  Future(407 [JYU1997]),
#  Future(415 [JYZ1997]),
#  Future(423 [JYH1998]),
#  Future(431 [JYM1998]),
#  Future(439 [JYU1998]),
#  Future(447 [JYZ1998]),
#  Future(455 [JYH1999]),
#  Future(463 [JYM1999]),
#  Future(471 [JYU1999]),
#  Future(479 [JYZ1999]),
#  Future(487 [JYH2000]),
#  Future(495 [JYM2000]),
#  Future(504 [JYU2000]),
#  Future(512 [JYZ2000]),
#  Future(520 [JYH2001]),
#  Future(528 [JYM2001]),
#  Future(535 [JYU2001]),
#  Future(543 [JYZ2001]),
#  Future(552 [JYH2002]),
#  Future(559 [JYM2002]),
#  Future(567 [JYU2002]),
#  Future(575 [JYZ2002]),
#  Future(583 [JYH2003]),
#  Future(590 [JYM2003]),
#  Future(598 [JYU2003]),
#  Future(604 [JYZ2003]),
#  Future(612 [JYH2004]),
#  Future(619 [JYM2004]),
#  Future(627 [JYU2004]),
#  Future(634 [JYZ2004]),
#  Future(641 [JYH2005]),
#  Future(648 [JYM2005]),
#  Future(656 [JYU2005]),
#  Future(662 [JYZ2005]),
#  Future(669 [JYH2006]),
#  Future(678 [JYM2006]),
#  Future(686 [JYU2006]),
#  Future(694 [JYZ2006]),
#  Future(702 [JYH2007]),
#  Future(710 [JYM2007]),
#  Future(717 [JYU2007]),
#  Future(725 [JYZ2007]),
#  Future(733 [JYH2008]),
#  Future(741 [JYM2008]),
#  Future(749 [JYU2008]),
#  Future(757 [JYZ2008]),
#  Future(765 [JYH2009]),
#  Future(773 [JYM2009]),
#  Future(781 [JYU2009]),
#  Future(789 [JYZ2009]),
#  Future(797 [JYH2010]),
#  Future(805 [JYM2010]),
#  Future(813 [JYU2010]),
#  Future(821 [JYZ2010]),
#  Future(829 [JYH2011]),
#  Future(837 [JYM2011]),
#  Future(846 [JYU2011]),
#  Future(854 [JYZ2011]),
#  Future(862 [JYH2012]),
#  Future(870 [JYM2012]),
#  Future(877 [JYU2012]),
#  Future(885 [JYZ2012]),
#  Future(894 [JYH2013]),
#  Future(901 [JYM2013]),
#  Future(909 [JYU2013]),
#  Future(917 [JYZ2013]),
#  Future(925 [JYH2014]),
#  Future(933 [JYM2014]),
#  Future(941 [JYU2014]),
#  Future(949 [JYZ2014]),
#  Future(957 [JYH2015]),
#  Future(965 [JYM2015]),
#  Future(973 [JYU2015]),
#  Future(981 [JYZ2015]),
#  Future(989 [JYH2016]),
#  Future(997 [JYM2016]),
#  Future(1006 [JYU2016]),
#  Future(1014 [JYZ2016]),
#  Future(1021 [JYH2017]),
#  Future(1025 [JYJ2017]),
#  Future(1028 [JYK2017]),
#  Future(1032 [JYM2017]),
#  Future(1035 [JYN2017]),
#  Future(1038 [JYQ2017]),
#  Future(1042 [JYU2017]),
#  Future(1045 [JYV2017]),
#  Future(1048 [JYX2017]),
#  Future(1052 [JYZ2017]),
#  Future(1055 [JYF2018]),
#  Future(1058 [JYG2018]),
#  Future(1062 [JYH2018]),
#  Future(1065 [JYJ2018]),
#  Future(1068 [JYK2018]),
#  Future(1072 [JYM2018]),
#  Future(1075 [JYN2018]),
#  Future(1078 [JYQ2018]),
#  Future(1081 [JYU2018]),
#  Future(1085 [JYV2018]),
#  Future(1089 [JYX2018]),
#  Future(1091 [JYZ2018]),
#  Future(1095 [JYF2019]),
#  Future(1098 [JYG2019]),
#  Future(1102 [JYH2019]),
#  Future(1107 [JYM2019]),
#  Future(1114 [JYU2019]),
#  Future(1120 [JYZ2019]),
#  Future(1127 [JYH2020]),
#  Future(1132 [JYM2020]),
#  Future(1138 [JYU2020]),
#  Future(1142 [JYZ2020]),
#  Future(1147 [JYH2021]),
#  Future(1151 [JYM2021]),
#  Future(1156 [JYU2021]),
#  Future(1160 [JYZ2021]),
#  Future(1165 [JYH2022]),
#  Future(1169 [JYM2022]),
#  Future(1174 [JYU2022]),
#  Future(1178 [JYZ2022])]

# %%
jy_dates = [(x.symbol, x.start_date, x.end_date) for x in jy_contracts]

# %%
jy_dates
# Out:
# [('JYH1978',
#   Timestamp('1977-06-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1978-03-13 00:00:00+0000', tz='UTC')),
#  ('JYM1978',
#   Timestamp('1977-06-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1978-06-19 00:00:00+0000', tz='UTC')),
#  ('JYU1978',
#   Timestamp('1978-01-17 00:00:00+0000', tz='UTC'),
#   Timestamp('1978-09-18 00:00:00+0000', tz='UTC')),
#  ('JYZ1978',
#   Timestamp('1978-03-15 00:00:00+0000', tz='UTC'),
#   Timestamp('1978-12-18 00:00:00+0000', tz='UTC')),
#  ('JYH1979',
#   Timestamp('1978-06-13 00:00:00+0000', tz='UTC'),
#   Timestamp('1979-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM1979',
#   Timestamp('1978-09-20 00:00:00+0000', tz='UTC'),
#   Timestamp('1979-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU1979',
#   Timestamp('1978-07-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1979-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ1979',
#   Timestamp('1978-10-30 00:00:00+0000', tz='UTC'),
#   Timestamp('1979-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH1980',
#   Timestamp('1979-06-20 00:00:00+0000', tz='UTC'),
#   Timestamp('1980-03-17 00:00:00+0000', tz='UTC')),
#  ('JYM1980',
#   Timestamp('1979-09-12 00:00:00+0000', tz='UTC'),
#   Timestamp('1980-06-16 00:00:00+0000', tz='UTC')),
#  ('JYU1980',
#   Timestamp('1980-01-08 00:00:00+0000', tz='UTC'),
#   Timestamp('1980-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ1980',
#   Timestamp('1980-03-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1980-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH1981',
#   Timestamp('1980-05-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1981-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM1981',
#   Timestamp('1980-09-22 00:00:00+0000', tz='UTC'),
#   Timestamp('1981-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU1981',
#   Timestamp('1980-12-22 00:00:00+0000', tz='UTC'),
#   Timestamp('1981-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ1981',
#   Timestamp('1981-01-30 00:00:00+0000', tz='UTC'),
#   Timestamp('1981-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH1982',
#   Timestamp('1981-06-02 00:00:00+0000', tz='UTC'),
#   Timestamp('1982-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM1982',
#   Timestamp('1981-10-07 00:00:00+0000', tz='UTC'),
#   Timestamp('1982-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU1982',
#   Timestamp('1982-01-14 00:00:00+0000', tz='UTC'),
#   Timestamp('1982-09-13 00:00:00+0000', tz='UTC')),
#  ('JYZ1982',
#   Timestamp('1982-03-22 00:00:00+0000', tz='UTC'),
#   Timestamp('1982-12-13 00:00:00+0000', tz='UTC')),
#  ('JYH1983',
#   Timestamp('1982-06-02 00:00:00+0000', tz='UTC'),
#   Timestamp('1983-03-14 00:00:00+0000', tz='UTC')),
#  ('JYM1983',
#   Timestamp('1982-09-20 00:00:00+0000', tz='UTC'),
#   Timestamp('1983-06-13 00:00:00+0000', tz='UTC')),
#  ('JYU1983',
#   Timestamp('1983-01-20 00:00:00+0000', tz='UTC'),
#   Timestamp('1983-09-19 00:00:00+0000', tz='UTC')),
#  ('JYZ1983',
#   Timestamp('1983-02-02 00:00:00+0000', tz='UTC'),
#   Timestamp('1983-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH1984',
#   Timestamp('1983-06-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1984-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM1984',
#   Timestamp('1983-08-02 00:00:00+0000', tz='UTC'),
#   Timestamp('1984-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU1984',
#   Timestamp('1983-12-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1984-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ1984',
#   Timestamp('1984-01-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1984-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH1985',
#   Timestamp('1984-03-28 00:00:00+0000', tz='UTC'),
#   Timestamp('1985-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM1985',
#   Timestamp('1984-06-19 00:00:00+0000', tz='UTC'),
#   Timestamp('1985-06-17 00:00:00+0000', tz='UTC')),
#  ('JYU1985',
#   Timestamp('1984-11-26 00:00:00+0000', tz='UTC'),
#   Timestamp('1985-09-16 00:00:00+0000', tz='UTC')),
#  ('JYZ1985',
#   Timestamp('1984-08-03 00:00:00+0000', tz='UTC'),
#   Timestamp('1985-12-16 00:00:00+0000', tz='UTC')),
#  ('JYH1986',
#   Timestamp('1985-04-01 00:00:00+0000', tz='UTC'),
#   Timestamp('1986-03-17 00:00:00+0000', tz='UTC')),
#  ('JYM1986',
#   Timestamp('1985-09-06 00:00:00+0000', tz='UTC'),
#   Timestamp('1986-06-16 00:00:00+0000', tz='UTC')),
#  ('JYU1986',
#   Timestamp('1985-10-04 00:00:00+0000', tz='UTC'),
#   Timestamp('1986-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ1986',
#   Timestamp('1985-09-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1986-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH1987',
#   Timestamp('1986-05-22 00:00:00+0000', tz='UTC'),
#   Timestamp('1987-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM1987',
#   Timestamp('1986-09-08 00:00:00+0000', tz='UTC'),
#   Timestamp('1987-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU1987',
#   Timestamp('1986-09-16 00:00:00+0000', tz='UTC'),
#   Timestamp('1987-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ1987',
#   Timestamp('1986-12-16 00:00:00+0000', tz='UTC'),
#   Timestamp('1987-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH1988',
#   Timestamp('1987-03-16 00:00:00+0000', tz='UTC'),
#   Timestamp('1988-03-14 00:00:00+0000', tz='UTC')),
#  ('JYM1988',
#   Timestamp('1987-04-06 00:00:00+0000', tz='UTC'),
#   Timestamp('1988-06-13 00:00:00+0000', tz='UTC')),
#  ('JYU1988',
#   Timestamp('1987-09-17 00:00:00+0000', tz='UTC'),
#   Timestamp('1988-09-19 00:00:00+0000', tz='UTC')),
#  ('JYZ1988',
#   Timestamp('1987-09-17 00:00:00+0000', tz='UTC'),
#   Timestamp('1988-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH1989',
#   Timestamp('1987-12-16 00:00:00+0000', tz='UTC'),
#   Timestamp('1989-03-13 00:00:00+0000', tz='UTC')),
#  ('JYM1989',
#   Timestamp('1988-04-11 00:00:00+0000', tz='UTC'),
#   Timestamp('1989-06-19 00:00:00+0000', tz='UTC')),
#  ('JYU1989',
#   Timestamp('1988-09-28 00:00:00+0000', tz='UTC'),
#   Timestamp('1989-09-18 00:00:00+0000', tz='UTC')),
#  ('JYZ1989',
#   Timestamp('1988-11-28 00:00:00+0000', tz='UTC'),
#   Timestamp('1989-12-18 00:00:00+0000', tz='UTC')),
#  ('JYH1990',
#   Timestamp('1989-02-15 00:00:00+0000', tz='UTC'),
#   Timestamp('1990-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM1990',
#   Timestamp('1989-06-23 00:00:00+0000', tz='UTC'),
#   Timestamp('1990-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU1990',
#   Timestamp('1989-09-18 00:00:00+0000', tz='UTC'),
#   Timestamp('1990-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ1990',
#   Timestamp('1989-12-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1990-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH1991',
#   Timestamp('1990-03-13 00:00:00+0000', tz='UTC'),
#   Timestamp('1991-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM1991',
#   Timestamp('1990-07-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1991-06-17 00:00:00+0000', tz='UTC')),
#  ('JYU1991',
#   Timestamp('1990-10-18 00:00:00+0000', tz='UTC'),
#   Timestamp('1991-09-16 00:00:00+0000', tz='UTC')),
#  ('JYZ1991',
#   Timestamp('1991-01-24 00:00:00+0000', tz='UTC'),
#   Timestamp('1991-12-16 00:00:00+0000', tz='UTC')),
#  ('JYH1992',
#   Timestamp('1991-02-01 00:00:00+0000', tz='UTC'),
#   Timestamp('1992-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM1992',
#   Timestamp('1991-04-29 00:00:00+0000', tz='UTC'),
#   Timestamp('1992-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU1992',
#   Timestamp('1991-08-07 00:00:00+0000', tz='UTC'),
#   Timestamp('1992-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ1992',
#   Timestamp('1991-09-11 00:00:00+0000', tz='UTC'),
#   Timestamp('1992-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH1993',
#   Timestamp('1991-11-25 00:00:00+0000', tz='UTC'),
#   Timestamp('1993-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM1993',
#   Timestamp('1992-07-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1993-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU1993',
#   Timestamp('1992-11-12 00:00:00+0000', tz='UTC'),
#   Timestamp('1993-09-13 00:00:00+0000', tz='UTC')),
#  ('JYZ1993',
#   Timestamp('1992-11-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1993-12-13 00:00:00+0000', tz='UTC')),
#  ('JYH1994',
#   Timestamp('1993-03-31 00:00:00+0000', tz='UTC'),
#   Timestamp('1994-03-14 00:00:00+0000', tz='UTC')),
#  ('JYM1994',
#   Timestamp('1993-03-09 00:00:00+0000', tz='UTC'),
#   Timestamp('1994-06-13 00:00:00+0000', tz='UTC')),
#  ('JYU1994',
#   Timestamp('1993-10-06 00:00:00+0000', tz='UTC'),
#   Timestamp('1994-09-19 00:00:00+0000', tz='UTC')),
#  ('JYZ1994',
#   Timestamp('1994-02-14 00:00:00+0000', tz='UTC'),
#   Timestamp('1994-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH1995',
#   Timestamp('1994-04-21 00:00:00+0000', tz='UTC'),
#   Timestamp('1995-03-13 00:00:00+0000', tz='UTC')),
#  ('JYM1995',
#   Timestamp('1994-04-18 00:00:00+0000', tz='UTC'),
#   Timestamp('1995-06-19 00:00:00+0000', tz='UTC')),
#  ('JYU1995',
#   Timestamp('1994-06-29 00:00:00+0000', tz='UTC'),
#   Timestamp('1995-09-18 00:00:00+0000', tz='UTC')),
#  ('JYZ1995',
#   Timestamp('1994-09-14 00:00:00+0000', tz='UTC'),
#   Timestamp('1995-12-18 00:00:00+0000', tz='UTC')),
#  ('JYH1996',
#   Timestamp('1994-10-25 00:00:00+0000', tz='UTC'),
#   Timestamp('1996-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM1996',
#   Timestamp('1995-02-09 00:00:00+0000', tz='UTC'),
#   Timestamp('1996-06-17 00:00:00+0000', tz='UTC')),
#  ('JYU1996',
#   Timestamp('1995-07-12 00:00:00+0000', tz='UTC'),
#   Timestamp('1996-09-16 00:00:00+0000', tz='UTC')),
#  ('JYZ1996',
#   Timestamp('1995-10-25 00:00:00+0000', tz='UTC'),
#   Timestamp('1996-12-16 00:00:00+0000', tz='UTC')),
#  ('JYH1997',
#   Timestamp('1996-02-05 00:00:00+0000', tz='UTC'),
#   Timestamp('1997-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM1997',
#   Timestamp('1996-06-27 00:00:00+0000', tz='UTC'),
#   Timestamp('1997-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU1997',
#   Timestamp('1996-07-15 00:00:00+0000', tz='UTC'),
#   Timestamp('1997-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ1997',
#   Timestamp('1996-12-04 00:00:00+0000', tz='UTC'),
#   Timestamp('1997-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH1998',
#   Timestamp('1997-04-15 00:00:00+0000', tz='UTC'),
#   Timestamp('1998-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM1998',
#   Timestamp('1997-08-07 00:00:00+0000', tz='UTC'),
#   Timestamp('1998-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU1998',
#   Timestamp('1997-09-16 00:00:00+0000', tz='UTC'),
#   Timestamp('1998-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ1998',
#   Timestamp('1997-10-21 00:00:00+0000', tz='UTC'),
#   Timestamp('1998-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH1999',
#   Timestamp('1998-02-19 00:00:00+0000', tz='UTC'),
#   Timestamp('1999-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM1999',
#   Timestamp('1998-06-10 00:00:00+0000', tz='UTC'),
#   Timestamp('1999-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU1999',
#   Timestamp('1998-09-08 00:00:00+0000', tz='UTC'),
#   Timestamp('1999-09-13 00:00:00+0000', tz='UTC')),
#  ('JYZ1999',
#   Timestamp('1998-10-16 00:00:00+0000', tz='UTC'),
#   Timestamp('1999-12-13 00:00:00+0000', tz='UTC')),
#  ('JYH2000',
#   Timestamp('1999-03-09 00:00:00+0000', tz='UTC'),
#   Timestamp('2000-03-13 00:00:00+0000', tz='UTC')),
#  ('JYM2000',
#   Timestamp('1999-06-08 00:00:00+0000', tz='UTC'),
#   Timestamp('2000-06-19 00:00:00+0000', tz='UTC')),
#  ('JYU2000',
#   Timestamp('1999-09-08 00:00:00+0000', tz='UTC'),
#   Timestamp('2000-09-18 00:00:00+0000', tz='UTC')),
#  ('JYZ2000',
#   Timestamp('1999-08-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2000-12-18 00:00:00+0000', tz='UTC')),
#  ('JYH2001',
#   Timestamp('2000-03-06 00:00:00+0000', tz='UTC'),
#   Timestamp('2001-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM2001',
#   Timestamp('2000-06-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2001-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU2001',
#   Timestamp('2000-09-08 00:00:00+0000', tz='UTC'),
#   Timestamp('2001-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ2001',
#   Timestamp('2000-10-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2001-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH2002',
#   Timestamp('2001-03-02 00:00:00+0000', tz='UTC'),
#   Timestamp('2002-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM2002',
#   Timestamp('2001-04-05 00:00:00+0000', tz='UTC'),
#   Timestamp('2002-06-17 00:00:00+0000', tz='UTC')),
#  ('JYU2002',
#   Timestamp('2001-04-05 00:00:00+0000', tz='UTC'),
#   Timestamp('2002-09-16 00:00:00+0000', tz='UTC')),
#  ('JYZ2002',
#   Timestamp('2001-06-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2002-12-16 00:00:00+0000', tz='UTC')),
#  ('JYH2003',
#   Timestamp('2001-09-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2003-03-17 00:00:00+0000', tz='UTC')),
#  ('JYM2003',
#   Timestamp('2001-12-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2003-06-16 00:00:00+0000', tz='UTC')),
#  ('JYU2003',
#   Timestamp('2002-03-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2003-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ2003',
#   Timestamp('2002-06-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2003-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH2004',
#   Timestamp('2002-09-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2004-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM2004',
#   Timestamp('2002-12-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2004-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU2004',
#   Timestamp('2003-03-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2004-09-13 00:00:00+0000', tz='UTC')),
#  ('JYZ2004',
#   Timestamp('2003-06-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2004-12-13 00:00:00+0000', tz='UTC')),
#  ('JYH2005',
#   Timestamp('2003-09-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2005-03-14 00:00:00+0000', tz='UTC')),
#  ('JYM2005',
#   Timestamp('2003-12-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2005-06-13 00:00:00+0000', tz='UTC')),
#  ('JYU2005',
#   Timestamp('2004-03-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2005-09-19 00:00:00+0000', tz='UTC')),
#  ('JYZ2005',
#   Timestamp('2004-06-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2005-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH2006',
#   Timestamp('2004-09-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2006-03-13 00:00:00+0000', tz='UTC')),
#  ('JYM2006',
#   Timestamp('2004-12-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2006-06-19 00:00:00+0000', tz='UTC')),
#  ('JYU2006',
#   Timestamp('2005-03-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2006-09-18 00:00:00+0000', tz='UTC')),
#  ('JYZ2006',
#   Timestamp('2005-06-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2006-12-18 00:00:00+0000', tz='UTC')),
#  ('JYH2007',
#   Timestamp('2005-09-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2007-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM2007',
#   Timestamp('2005-12-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2007-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU2007',
#   Timestamp('2006-03-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2007-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ2007',
#   Timestamp('2006-06-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2007-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH2008',
#   Timestamp('2006-09-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2008-03-17 00:00:00+0000', tz='UTC')),
#  ('JYM2008',
#   Timestamp('2006-12-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2008-06-16 00:00:00+0000', tz='UTC')),
#  ('JYU2008',
#   Timestamp('2007-03-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2008-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ2008',
#   Timestamp('2007-06-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2008-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH2009',
#   Timestamp('2007-09-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2009-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM2009',
#   Timestamp('2007-12-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2009-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU2009',
#   Timestamp('2008-03-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2009-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ2009',
#   Timestamp('2008-06-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2009-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH2010',
#   Timestamp('2008-09-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM2010',
#   Timestamp('2008-12-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU2010',
#   Timestamp('2009-03-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-09-13 00:00:00+0000', tz='UTC')),
#  ('JYZ2010',
#   Timestamp('2009-06-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-12-13 00:00:00+0000', tz='UTC')),
#  ('JYH2011',
#   Timestamp('2009-09-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM2011',
#   Timestamp('2009-12-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU2011',
#   Timestamp('2010-03-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-09-20 00:00:00+0000', tz='UTC')),
#  ('JYZ2011',
#   Timestamp('2010-06-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH2012',
#   Timestamp('2010-09-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM2012',
#   Timestamp('2010-12-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU2012',
#   Timestamp('2011-03-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ2012',
#   Timestamp('2011-06-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH2013',
#   Timestamp('2011-10-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM2013',
#   Timestamp('2011-12-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-06-17 00:00:00+0000', tz='UTC')),
#  ('JYU2013',
#   Timestamp('2012-03-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-09-16 00:00:00+0000', tz='UTC')),
#  ('JYZ2013',
#   Timestamp('2012-06-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-12-16 00:00:00+0000', tz='UTC')),
#  ('JYH2014',
#   Timestamp('2012-09-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-03-17 00:00:00+0000', tz='UTC')),
#  ('JYM2014',
#   Timestamp('2012-12-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-06-16 00:00:00+0000', tz='UTC')),
#  ('JYU2014',
#   Timestamp('2013-03-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ2014',
#   Timestamp('2013-06-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH2015',
#   Timestamp('2013-08-09 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM2015',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU2015',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ2015',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH2016',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-03-14 00:00:00+0000', tz='UTC')),
#  ('JYM2016',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-06-13 00:00:00+0000', tz='UTC')),
#  ('JYU2016',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-09-19 00:00:00+0000', tz='UTC')),
#  ('JYZ2016',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH2017',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-03-13 00:00:00+0000', tz='UTC')),
#  ('JYJ2017',
#   Timestamp('2017-02-27 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-04-17 00:00:00+0000', tz='UTC')),
#  ('JYK2017',
#   Timestamp('2017-02-27 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-05-15 00:00:00+0000', tz='UTC')),
#  ('JYM2017',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-06-19 00:00:00+0000', tz='UTC')),
#  ('JYN2017',
#   Timestamp('2017-02-27 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-07-17 00:00:00+0000', tz='UTC')),
#  ('JYQ2017',
#   Timestamp('2017-04-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-08-14 00:00:00+0000', tz='UTC')),
#  ('JYU2017',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-09-18 00:00:00+0000', tz='UTC')),
#  ('JYV2017',
#   Timestamp('2017-05-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-10-16 00:00:00+0000', tz='UTC')),
#  ('JYX2017',
#   Timestamp('2017-07-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-11-13 00:00:00+0000', tz='UTC')),
#  ('JYZ2017',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-12-18 00:00:00+0000', tz='UTC')),
#  ('JYF2018',
#   Timestamp('2017-08-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-01-12 00:00:00+0000', tz='UTC')),
#  ('JYG2018',
#   Timestamp('2017-10-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-02-16 00:00:00+0000', tz='UTC')),
#  ('JYH2018',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-03-19 00:00:00+0000', tz='UTC')),
#  ('JYJ2018',
#   Timestamp('2017-11-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-04-16 00:00:00+0000', tz='UTC')),
#  ('JYK2018',
#   Timestamp('2018-01-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-05-14 00:00:00+0000', tz='UTC')),
#  ('JYM2018',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-06-18 00:00:00+0000', tz='UTC')),
#  ('JYN2018',
#   Timestamp('2018-02-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-07-16 00:00:00+0000', tz='UTC')),
#  ('JYQ2018',
#   Timestamp('2018-04-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-08-13 00:00:00+0000', tz='UTC')),
#  ('JYU2018',
#   Timestamp('2013-09-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-09-17 00:00:00+0000', tz='UTC')),
#  ('JYV2018',
#   Timestamp('2018-05-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-10-15 00:00:00+0000', tz='UTC')),
#  ('JYX2018',
#   Timestamp('2018-07-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYZ2018',
#   Timestamp('2014-02-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYF2019',
#   Timestamp('2018-08-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYG2019',
#   Timestamp('2018-10-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYH2019',
#   Timestamp('2014-03-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYM2019',
#   Timestamp('2014-06-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYU2019',
#   Timestamp('2014-09-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYZ2019',
#   Timestamp('2014-12-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYH2020',
#   Timestamp('2015-03-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYM2020',
#   Timestamp('2015-06-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYU2020',
#   Timestamp('2015-09-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYZ2020',
#   Timestamp('2015-12-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYH2021',
#   Timestamp('2016-03-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYM2021',
#   Timestamp('2016-06-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYU2021',
#   Timestamp('2016-09-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYZ2021',
#   Timestamp('2016-12-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYH2022',
#   Timestamp('2017-03-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYM2022',
#   Timestamp('2017-06-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYU2022',
#   Timestamp('2017-09-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC')),
#  ('JYZ2022',
#   Timestamp('2017-12-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-02 00:00:00+0000', tz='UTC'))]

# %%
his = history(
    assets=[a],
    end_dt=pd.Timestamp('2017-01-03'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
    )
# Out:
# Exception ignored in: 'zipline.assets.continuous_futures.OrderedContracts.contract_before_auto_close'
# AttributeError: 'NoneType' object has no attribute 'next'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-889f8f54dfcf> in <module>()
#       5     frequency='1d',
#       6     field='price',
# ----> 7     data_frequency='daily'
#       8     )
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in get_history_window(self, assets, end_dt, bar_count, frequency, field, data_frequency, ffill)
#     955             if field == "price":
#     956                 df = self._get_history_daily_window(assets, end_dt, bar_count,
# --> 957                                                     "close", data_frequency)
#     958             else:
#     959                 df = self._get_history_daily_window(assets, end_dt, bar_count,
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_history_daily_window(self, assets, end_dt, bar_count, field_to_use, data_frequency)
#     802
#     803         data = self._get_history_daily_window_data(
# --> 804             assets, days_for_window, end_dt, field_to_use, data_frequency
#     805         )
#     806         return pd.DataFrame(
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_history_daily_window_data(self, assets, days_for_window, end_dt, field_to_use, data_frequency)
#     825                 field_to_use,
#     826                 days_for_window,
# --> 827                 extra_slot=False
#     828             )
#     829         else:
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_daily_window_data(self, assets, field, days_in_window, extra_slot)
#    1108                                                 days_in_window,
#    1109                                                 field,
# -> 1110                                                 extra_slot)
#    1111             if extra_slot:
#    1112                 return_array[:len(return_array) - 1, :] = data
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in history(self, assets, dts, field, is_perspective_after)
#     548                                              dts,
#     549                                              field,
# --> 550                                              is_perspective_after)
#     551         end_ix = self._calendar.searchsorted(dts[-1])
#     552
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in _ensure_sliding_windows(self, assets, dts, field, is_perspective_after)
#     430                 adj_dts = prefetch_dts
#     431             prefetch_len = len(prefetch_dts)
# --> 432             array = self._array(prefetch_dts, needed_assets, field)
#     433
#     434             if field == 'sid':
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in _array(self, dts, assets, field)
#     572             dts[0],
#     573             dts[-1],
# --> 574             assets,
#     575         )[0]
#     576
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\dispatch_bar_reader.py in load_raw_arrays(self, fields, start_dt, end_dt, sids)
#     118                                                 end_dt,
#     119                                                 sid_groups[t])
# --> 120             for t in asset_types if sid_groups[t]}
#     121
#     122         results = []
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\dispatch_bar_reader.py in <dictcomp>(.0)
#     118                                                 end_dt,
#     119                                                 sid_groups[t])
# --> 120             for t in asset_types if sid_groups[t]}
#     121
#     122         results = []
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\continuous_future_reader.py in load_raw_arrays(self, columns, start_date, end_date, assets)
#      37                 start_date,
#      38                 end_date,
# ---> 39                 asset.offset
#      40             )
#      41
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\roll_finder.py in get_rolls(self, root_symbol, start, end, offset)
#      89         """
#      90         oc = self.asset_finder.get_ordered_contracts(root_symbol)
# ---> 91         front = self._get_active_contract_at_offset(root_symbol, end, 0)
#      92         back = oc.contract_at_offset(front, 1, end.value)
#      93         if back is not None:
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\roll_finder.py in _get_active_contract_at_offset(self, root_symbol, dt, offset)
#      39         session = self.trading_calendar.minute_to_session_label(dt)
#      40         front = oc.contract_before_auto_close(session.value)
# ---> 41         back = oc.contract_at_offset(front, 1, dt.value)
#      42         if back is None:
#      43             return front
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\continuous_futures.pyx in zipline.assets.continuous_futures.OrderedContracts.contract_at_offset (zipline/assets\continuous_futures.c:7309)()
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\continuous_futures.pyx in zipline.assets.continuous_futures.OrderedContracts.contract_at_offset (zipline/assets\continuous_futures.c:7061)()
#
# KeyError: 0

# %%
his
# Out:
#                            ContinuousFuture(91570626912911360 [ES, 0, volume, mul])
# 1998-08-12 00:00:00+00:00                                            1111.16
# 1998-08-13 00:00:00+00:00                                            1096.64
# 1998-08-14 00:00:00+00:00                                            1084.67
# 1998-08-17 00:00:00+00:00                                            1105.05
# 1998-08-18 00:00:00+00:00                                            1127.21
# 1998-08-19 00:00:00+00:00                                            1123.90
# 1998-08-20 00:00:00+00:00                                            1115.24
# 1998-08-21 00:00:00+00:00                                            1108.11
# 1998-08-24 00:00:00+00:00                                            1113.20
# 1998-08-25 00:00:00+00:00                                            1115.75
# 1998-08-26 00:00:00+00:00                                            1108.62
# 1998-08-27 00:00:00+00:00                                            1056.91
# 1998-08-28 00:00:00+00:00                                            1052.32
# 1998-08-31 00:00:00+00:00                                             972.33
# 1998-09-01 00:00:00+00:00                                            1018.95
# 1998-09-02 00:00:00+00:00                                            1009.78
# 1998-09-03 00:00:00+00:00                                            1004.43
# 1998-09-04 00:00:00+00:00                                             995.26
# 1998-09-08 00:00:00+00:00                                            1045.19
# 1998-09-09 00:00:00+00:00                                            1023.28
# 1998-09-10 00:00:00+00:00                                             990.67
# 1998-09-11 00:00:00+00:00                                            1034.10
# 1998-09-14 00:00:00+00:00                                            1050.51
# 1998-09-15 00:00:00+00:00                                            1058.08
# 1998-09-16 00:00:00+00:00                                            1068.18
# 1998-09-17 00:00:00+00:00                                            1037.63
# 1998-09-18 00:00:00+00:00                                            1039.65
# 1998-09-21 00:00:00+00:00                                            1042.18
# 1998-09-22 00:00:00+00:00                                            1049.25
# 1998-09-23 00:00:00+00:00                                            1089.13
# ...                                                                      ...
# 1998-11-19 00:00:00+00:00                                            1169.67
# 1998-11-20 00:00:00+00:00                                            1178.76
# 1998-11-23 00:00:00+00:00                                            1205.77
# 1998-11-24 00:00:00+00:00                                            1197.69
# 1998-11-25 00:00:00+00:00                                            1199.46
# 1998-11-27 00:00:00+00:00                                            1206.78
# 1998-11-30 00:00:00+00:00                                            1173.71
# 1998-12-01 00:00:00+00:00                                            1186.33
# 1998-12-02 00:00:00+00:00                                            1183.81
# 1998-12-03 00:00:00+00:00                                            1163.86
# 1998-12-04 00:00:00+00:00                                            1191.64
# 1998-12-07 00:00:00+00:00                                            1199.71
# 1998-12-08 00:00:00+00:00                                            1192.90
# 1998-12-09 00:00:00+00:00                                            1196.18
# 1998-12-10 00:00:00+00:00                                            1177.75
# 1998-12-11 00:00:00+00:00                                            1175.50
# 1998-12-14 00:00:00+00:00                                            1148.00
# 1998-12-15 00:00:00+00:00                                            1174.50
# 1998-12-16 00:00:00+00:00                                            1175.25
# 1998-12-17 00:00:00+00:00                                            1192.50
# 1998-12-18 00:00:00+00:00                                            1197.25
# 1998-12-21 00:00:00+00:00                                            1214.25
# 1998-12-22 00:00:00+00:00                                            1216.50
# 1998-12-23 00:00:00+00:00                                            1243.25
# 1998-12-24 00:00:00+00:00                                            1239.00
# 1998-12-28 00:00:00+00:00                                            1233.75
# 1998-12-29 00:00:00+00:00                                            1254.50
# 1998-12-30 00:00:00+00:00                                            1242.00
# 1998-12-31 00:00:00+00:00                                            1245.75
# 1999-01-04 00:00:00+00:00                                            1241.00
#
# [100 rows x 1 columns]

# %%
pd.Timestamp.today() - pd.Timedelta(days=3)
# Out:
# Timestamp('2018-11-03 09:59:19.456114')

# %%
from zipline.data import continuous_future_reader

# %%
reader = continuous_future_reader

# %%
reader
# Out:
# <module 'zipline.data.continuous_future_reader' from 'C:\\Users\\tomek\\Anaconda3\\envs\\env_zipline\\lib\\site-packages\\zipline\\data\\continuous_future_reader.py'>

# %%
dir(reader)
# Out:
# ['ContinuousFutureMinuteBarReader',
#  'ContinuousFutureSessionBarReader',
#  'SessionBarReader',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'np',
#  'pd']

# %%
jy_sid = bundle_data.asset_finder.lookup_future_symbol('ESH2018').sid
start_dt = pd.Timestamp('2018-1-1', tz='UTC', offset='C')
oc = bundle_data.asset_finder.get_ordered_contracts('ES')
chain = oc.active_chain(jy_sid, start_dt.value)
all_chain = bundle_data.asset_finder.retrieve_all(chain)
all_chain
# Out:
# [Future(1061 [ESH2018]),
#  Future(1071 [ESM2018]),
#  Future(1083 [ESU2018]),
#  Future(1093 [ESZ2018]),
#  Future(1101 [ESH2019])]

# %%
jy_sid
# Out:
# 1061

# %%
oc

# %%
dir(oc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_end_date',
#  '_head_contract',
#  '_start_date',
#  'active_chain',
#  'chain_predicate',
#  'contract_at_offset',
#  'contract_before_auto_close',
#  'end_date',
#  'root_symbol',
#  'sid_to_contract',
#  'start_date']

# %%
oc.contract_at_offset?

# %%
oc.active_chain?

# %%
oc.sid_to_contract?

# %%
es = bundle_data.asset_finder.lookup_future_symbol('ESH2018')

# %%
es
# Out:
# Future(643 [ESH2018])

# %%
es.start_date
# Out:
# Timestamp('2016-12-16 00:00:00+0000', tz='UTC')

# %%
import pdb

# %%
pdb.run(history(
    assets=[a],
    end_dt=pd.Timestamp('2017-01-03'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
    ))
# Out:
# Exception ignored in: 'zipline.assets.continuous_futures.OrderedContracts.contract_before_auto_close'
# AttributeError: 'NoneType' object has no attribute 'next'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8e2ea05791de> in <module>()
#       5     frequency='1d',
#       6     field='price',
# ----> 7     data_frequency='daily'
#       8     ))
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in get_history_window(self, assets, end_dt, bar_count, frequency, field, data_frequency, ffill)
#     955             if field == "price":
#     956                 df = self._get_history_daily_window(assets, end_dt, bar_count,
# --> 957                                                     "close", data_frequency)
#     958             else:
#     959                 df = self._get_history_daily_window(assets, end_dt, bar_count,
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_history_daily_window(self, assets, end_dt, bar_count, field_to_use, data_frequency)
#     802
#     803         data = self._get_history_daily_window_data(
# --> 804             assets, days_for_window, end_dt, field_to_use, data_frequency
#     805         )
#     806         return pd.DataFrame(
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_history_daily_window_data(self, assets, days_for_window, end_dt, field_to_use, data_frequency)
#     825                 field_to_use,
#     826                 days_for_window,
# --> 827                 extra_slot=False
#     828             )
#     829         else:
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_daily_window_data(self, assets, field, days_in_window, extra_slot)
#    1108                                                 days_in_window,
#    1109                                                 field,
# -> 1110                                                 extra_slot)
#    1111             if extra_slot:
#    1112                 return_array[:len(return_array) - 1, :] = data
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in history(self, assets, dts, field, is_perspective_after)
#     548                                              dts,
#     549                                              field,
# --> 550                                              is_perspective_after)
#     551         end_ix = self._calendar.searchsorted(dts[-1])
#     552
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in _ensure_sliding_windows(self, assets, dts, field, is_perspective_after)
#     430                 adj_dts = prefetch_dts
#     431             prefetch_len = len(prefetch_dts)
# --> 432             array = self._array(prefetch_dts, needed_assets, field)
#     433
#     434             if field == 'sid':
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in _array(self, dts, assets, field)
#     572             dts[0],
#     573             dts[-1],
# --> 574             assets,
#     575         )[0]
#     576
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\dispatch_bar_reader.py in load_raw_arrays(self, fields, start_dt, end_dt, sids)
#     118                                                 end_dt,
#     119                                                 sid_groups[t])
# --> 120             for t in asset_types if sid_groups[t]}
#     121
#     122         results = []
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\dispatch_bar_reader.py in <dictcomp>(.0)
#     118                                                 end_dt,
#     119                                                 sid_groups[t])
# --> 120             for t in asset_types if sid_groups[t]}
#     121
#     122         results = []
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\continuous_future_reader.py in load_raw_arrays(self, columns, start_date, end_date, assets)
#      37                 start_date,
#      38                 end_date,
# ---> 39                 asset.offset
#      40             )
#      41
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\roll_finder.py in get_rolls(self, root_symbol, start, end, offset)
#      89         """
#      90         oc = self.asset_finder.get_ordered_contracts(root_symbol)
# ---> 91         front = self._get_active_contract_at_offset(root_symbol, end, 0)
#      92         back = oc.contract_at_offset(front, 1, end.value)
#      93         if back is not None:
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\roll_finder.py in _get_active_contract_at_offset(self, root_symbol, dt, offset)
#      39         session = self.trading_calendar.minute_to_session_label(dt)
#      40         front = oc.contract_before_auto_close(session.value)
# ---> 41         back = oc.contract_at_offset(front, 1, dt.value)
#      42         if back is None:
#      43             return front
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\continuous_futures.pyx in zipline.assets.continuous_futures.OrderedContracts.contract_at_offset (zipline/assets\continuous_futures.c:7309)()
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\continuous_futures.pyx in zipline.assets.continuous_futures.OrderedContracts.contract_at_offset (zipline/assets\continuous_futures.c:7061)()
#
# KeyError: 0

# %%
history(
    assets=[a],
    end_dt=pd.Timestamp('2017-01-03'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
    )
# Out:
# Exception ignored in: 'zipline.assets.continuous_futures.OrderedContracts.contract_before_auto_close'
# AttributeError: 'NoneType' object has no attribute 'next'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-52e0a68568c0> in <module>()
#       5     frequency='1d',
#       6     field='price',
# ----> 7     data_frequency='daily'
#       8     )
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in get_history_window(self, assets, end_dt, bar_count, frequency, field, data_frequency, ffill)
#     955             if field == "price":
#     956                 df = self._get_history_daily_window(assets, end_dt, bar_count,
# --> 957                                                     "close", data_frequency)
#     958             else:
#     959                 df = self._get_history_daily_window(assets, end_dt, bar_count,
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_history_daily_window(self, assets, end_dt, bar_count, field_to_use, data_frequency)
#     802
#     803         data = self._get_history_daily_window_data(
# --> 804             assets, days_for_window, end_dt, field_to_use, data_frequency
#     805         )
#     806         return pd.DataFrame(
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_history_daily_window_data(self, assets, days_for_window, end_dt, field_to_use, data_frequency)
#     825                 field_to_use,
#     826                 days_for_window,
# --> 827                 extra_slot=False
#     828             )
#     829         else:
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\data_portal.py in _get_daily_window_data(self, assets, field, days_in_window, extra_slot)
#    1108                                                 days_in_window,
#    1109                                                 field,
# -> 1110                                                 extra_slot)
#    1111             if extra_slot:
#    1112                 return_array[:len(return_array) - 1, :] = data
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in history(self, assets, dts, field, is_perspective_after)
#     548                                              dts,
#     549                                              field,
# --> 550                                              is_perspective_after)
#     551         end_ix = self._calendar.searchsorted(dts[-1])
#     552
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in _ensure_sliding_windows(self, assets, dts, field, is_perspective_after)
#     430                 adj_dts = prefetch_dts
#     431             prefetch_len = len(prefetch_dts)
# --> 432             array = self._array(prefetch_dts, needed_assets, field)
#     433
#     434             if field == 'sid':
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\history_loader.py in _array(self, dts, assets, field)
#     572             dts[0],
#     573             dts[-1],
# --> 574             assets,
#     575         )[0]
#     576
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\dispatch_bar_reader.py in load_raw_arrays(self, fields, start_dt, end_dt, sids)
#     118                                                 end_dt,
#     119                                                 sid_groups[t])
# --> 120             for t in asset_types if sid_groups[t]}
#     121
#     122         results = []
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\dispatch_bar_reader.py in <dictcomp>(.0)
#     118                                                 end_dt,
#     119                                                 sid_groups[t])
# --> 120             for t in asset_types if sid_groups[t]}
#     121
#     122         results = []
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\data\continuous_future_reader.py in load_raw_arrays(self, columns, start_date, end_date, assets)
#      37                 start_date,
#      38                 end_date,
# ---> 39                 asset.offset
#      40             )
#      41
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\roll_finder.py in get_rolls(self, root_symbol, start, end, offset)
#      89         """
#      90         oc = self.asset_finder.get_ordered_contracts(root_symbol)
# ---> 91         front = self._get_active_contract_at_offset(root_symbol, end, 0)
#      92         back = oc.contract_at_offset(front, 1, end.value)
#      93         if back is not None:
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\roll_finder.py in _get_active_contract_at_offset(self, root_symbol, dt, offset)
#      39         session = self.trading_calendar.minute_to_session_label(dt)
#      40         front = oc.contract_before_auto_close(session.value)
# ---> 41         back = oc.contract_at_offset(front, 1, dt.value)
#      42         if back is None:
#      43             return front
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\continuous_futures.pyx in zipline.assets.continuous_futures.OrderedContracts.contract_at_offset (zipline/assets\continuous_futures.c:7309)()
#
# ~\Anaconda3\envs\env_zipline\lib\site-packages\zipline\assets\continuous_futures.pyx in zipline.assets.continuous_futures.OrderedContracts.contract_at_offset (zipline/assets\continuous_futures.c:7061)()
#
# KeyError: 0
