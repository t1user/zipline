# %%
import os
import pandas as pd
from zipline.data import bundles
from zipline.data.data_portal import DataPortal
from zipline.utils.calendars import get_calendar
from zipline.assets._assets import Future
from zipline.utils.run_algo import load_extensions

# Load extensions.py; this allows you access to custom bundles
load_extensions(
    default=True,
    extensions=[],
    strict=True,
    environ=os.environ,
)

# Set-Up Pricing Data Access
trading_calendar = get_calendar('NYSE')
bundle = 'futures'
bundle_data = bundles.load(bundle)

data = DataPortal(
    bundle_data.asset_finder,
    trading_calendar=trading_calendar,
    first_trading_day=bundle_data.equity_daily_bar_reader.first_trading_day,
    equity_minute_reader=None,
    equity_daily_reader=bundle_data.equity_daily_bar_reader,
    future_daily_reader=bundle_data.equity_daily_bar_reader,
    adjustment_reader=bundle_data.adjustment_reader,
)

# %%
future = bundle_data.asset_finder.lookup_future_symbol
continuous_future = bundle_data.asset_finder.create_continuous_future
history = data.get_history_window

# %%
contracts = [
    # rates
    'ED', # eurodollars
    'TY', # 10y T-note
    'FV', # 5y T-note
    'TU', # 2y T-note
    'US', # U.S. Treasury bond
    'FF', # 30 day Fed funds
    'UL', # Ultra T-bond
    'SA', # 5y deliverable IRS
    'N1U',# 10y deliverable IRS
    'I3', # 30y deliverable IRS
    # equity
    'ES', # e-mini S&P 500
    'NQ', # e-mini Nasdaq 100
    'YM', # e-mini DowJones
    'MD', # e-mini S&P MidCap 400
    'NK', # Nikkei $5
    'XAF',# e-mini financial sector
    'XAK',# e-mini technology sector
    'XAP',# e-mini consumer staples sector
    'XAU',# e-mini utilities sector
    'XAY',# e-mini consumer discretionary sector
    # energy
    'CL', # WTI oil
    'NG', # natural gas
    'RB', # RBOB gasoline
    'HO', # NY Harbor ULSD
    'BZ', # Brent oil
    '71', # Ethanol
    # fx
    'EC', # EUR/USD
    'JY', # JPY/USD
    'BP', # GBP/USD
    'AD', # AUD/USD
    'CD', # CAD/USD
    'MP', # MXN/USD
    'SF', # CHF/USD
    # agriculture
    '_C', # Corn
    '_S', # Soybeans
    '_W', # Chicago SRW Wheat
    'BO', # Soybean oil
    'SM', # Soybean meal
    'LC', # Live cattle
    'KW', # KC HRW wheat
    'LN', # Lean hogs
    # metals
    'GC', # Gold
    'HG', # Copper
    'SI', # Silver
    'PL', # Platinum
    'PA', # Palladium
    ]

# %%
cont_contracts = [
    continuous_future(contract,
                        offset=0,
                        adjustment='mul',
                        roll_style='volume')
    for contract in contracts]

# %%
cont_contracts
# Out:
# [ContinuousFuture(91554134238494720, root_symbol='ED', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95799348633337856, root_symbol='TY', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91855400424505344, root_symbol='FV', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95794950586826752, root_symbol='TU', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96074226540281856, root_symbol='US', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91837808238460928, root_symbol='FF', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96066529958887424, root_symbol='UL', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95491485377560576, root_symbol='SA', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94066518307962880, root_symbol='N1U', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92661342447665152, root_symbol='I3', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91570626912911360, root_symbol='ES', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94101702680051712, root_symbol='NQ', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(97193529377357824, root_symbol='YM', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93805934052179968, root_symbol='MD', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94095105610285056, root_symbol='NK', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAF', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAK', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAP', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAU', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(96898860261113856, root_symbol='XAY', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90999980378095616, root_symbol='CL', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94090707563773952, root_symbol='NG', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95211109912477696, root_symbol='RB', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92410653796532224, root_symbol='HO', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90733898564173824, root_symbol='BZ', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(87592593843617792, root_symbol='71', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(91553034726866944, root_symbol='EC', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92984598866231296, root_symbol='JY', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90722903447896064, root_symbol='BP', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90428234331652096, root_symbol='AD', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90991184285073408, root_symbol='CD', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93819128191713280, root_symbol='MP', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95496982935699456, root_symbol='SF', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(98871384121344000, root_symbol='_C', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(98888976307388416, root_symbol='_S', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(98893374353899520, root_symbol='_W', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(90721803936268288, root_symbol='BO', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95504679517093888, root_symbol='SM', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93523359563841536, root_symbol='LC', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93263874819686400, root_symbol='KW', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(93535454191747072, root_symbol='LN', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92115984680288256, root_symbol='GC', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(92401857703510016, root_symbol='HG', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(95500281470582784, root_symbol='SI', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94659155075334144, root_symbol='PL', offset=0, roll_style='volume', adjustment='mul'),
#  ContinuousFuture(94647060447428608, root_symbol='PA', offset=0, roll_style='volume', adjustment='mul')]

# %%
import numpy as np
dates = pd.DataFrame(np.empty(2, dtype=[('from', 'datetime64[ns]'), ('to', 'datetime64[ns]')]))
dates
# Out:
#                            from                            to
# 0 1970-01-01 00:30:43.723966832 1970-01-01 00:30:43.723966832
# 1 1970-01-01 00:30:43.723967472 1970-01-01 00:30:43.723966832

# %%
dates = pd.DataFrame(cont_contracts)

# %%
dates = {cont.root_symbol: (cont.start_date, cont.end_date) for cont in cont_contracts}

# %%
dates
# Out:
# {'71': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'AD': (Timestamp('1987-01-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'BO': (Timestamp('1959-07-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'BP': (Timestamp('1975-02-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'BZ': (Timestamp('2011-10-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'CD': (Timestamp('1977-01-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'CL': (Timestamp('1983-03-30 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'EC': (Timestamp('1999-01-04 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'ED': (Timestamp('1982-02-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'ES': (Timestamp('1997-09-09 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'FF': (Timestamp('1988-10-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'FV': (Timestamp('1988-05-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'GC': (Timestamp('1974-12-31 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'HG': (Timestamp('1959-07-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'HO': (Timestamp('1979-03-06 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'I3': (Timestamp('2012-10-30 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'JY': (Timestamp('1976-08-02 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'KW': (Timestamp('1976-04-09 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'LC': (Timestamp('1964-11-30 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'LN': (Timestamp('1969-06-25 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'MD': (Timestamp('1992-02-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'MP': (Timestamp('1995-04-25 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'N1U': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'NG': (Timestamp('1990-04-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'NK': (Timestamp('1990-09-25 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'NQ': (Timestamp('1999-06-21 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'PA': (Timestamp('1977-01-05 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'PL': (Timestamp('1968-03-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'RB': (Timestamp('2005-10-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'SA': (Timestamp('2012-10-30 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'SF': (Timestamp('1975-02-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'SI': (Timestamp('1963-06-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'SM': (Timestamp('1959-07-02 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'TU': (Timestamp('1990-06-22 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'TY': (Timestamp('1982-05-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'UL': (Timestamp('2012-10-30 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'US': (Timestamp('1977-08-22 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'XAF': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'XAK': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'XAP': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'XAU': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'XAY': (Timestamp('2014-02-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  'YM': (Timestamp('1997-10-06 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  '_C': (Timestamp('1959-07-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  '_S': (Timestamp('1959-07-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  '_W': (Timestamp('1959-07-01 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC'))}

# %%
[(c.root_symbol, c.start_date) for c in cont_contracts]
# Out:
# [('ED', Timestamp('1982-02-01 00:00:00+0000', tz='UTC')),
#  ('TY', Timestamp('1982-05-03 00:00:00+0000', tz='UTC')),
#  ('FV', Timestamp('1988-05-20 00:00:00+0000', tz='UTC')),
#  ('TU', Timestamp('1990-06-22 00:00:00+0000', tz='UTC')),
#  ('US', Timestamp('1977-08-22 00:00:00+0000', tz='UTC')),
#  ('FF', Timestamp('1988-10-03 00:00:00+0000', tz='UTC')),
#  ('UL', Timestamp('2012-10-30 00:00:00+0000', tz='UTC')),
#  ('SA', Timestamp('2012-10-30 00:00:00+0000', tz='UTC')),
#  ('N1U', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('I3', Timestamp('2012-10-30 00:00:00+0000', tz='UTC')),
#  ('ES', Timestamp('1997-09-09 00:00:00+0000', tz='UTC')),
#  ('NQ', Timestamp('1999-06-21 00:00:00+0000', tz='UTC')),
#  ('YM', Timestamp('1997-10-06 00:00:00+0000', tz='UTC')),
#  ('MD', Timestamp('1992-02-13 00:00:00+0000', tz='UTC')),
#  ('NK', Timestamp('1990-09-25 00:00:00+0000', tz='UTC')),
#  ('XAF', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAK', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAP', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAU', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('XAY', Timestamp('2014-02-18 00:00:00+0000', tz='UTC')),
#  ('CL', Timestamp('1983-03-30 00:00:00+0000', tz='UTC')),
#  ('NG', Timestamp('1990-04-03 00:00:00+0000', tz='UTC')),
#  ('RB', Timestamp('2005-10-03 00:00:00+0000', tz='UTC')),
#  ('HO', Timestamp('1979-03-06 00:00:00+0000', tz='UTC')),
#  ('BZ', Timestamp('2011-10-03 00:00:00+0000', tz='UTC')),
#  ('EC', Timestamp('1999-01-04 00:00:00+0000', tz='UTC')),
#  ('JY', Timestamp('1976-08-02 00:00:00+0000', tz='UTC')),
#  ('BP', Timestamp('1975-02-13 00:00:00+0000', tz='UTC')),
#  ('AD', Timestamp('1987-01-13 00:00:00+0000', tz='UTC')),
#  ('CD', Timestamp('1977-01-17 00:00:00+0000', tz='UTC')),
#  ('MP', Timestamp('1995-04-25 00:00:00+0000', tz='UTC')),
#  ('SF', Timestamp('1975-02-13 00:00:00+0000', tz='UTC')),
#  ('_C', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('_S', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('_W', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('BO', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('SM', Timestamp('1959-07-02 00:00:00+0000', tz='UTC')),
#  ('LC', Timestamp('1964-11-30 00:00:00+0000', tz='UTC')),
#  ('KW', Timestamp('1976-04-09 00:00:00+0000', tz='UTC')),
#  ('LN', Timestamp('1969-06-25 00:00:00+0000', tz='UTC')),
#  ('GC', Timestamp('1974-12-31 00:00:00+0000', tz='UTC')),
#  ('HG', Timestamp('1959-07-01 00:00:00+0000', tz='UTC')),
#  ('SI', Timestamp('1963-06-13 00:00:00+0000', tz='UTC')),
#  ('PL', Timestamp('1968-03-01 00:00:00+0000', tz='UTC')),
#  ('PA', Timestamp('1977-01-05 00:00:00+0000', tz='UTC'))]

# %%
rb =

# %%
h = history(
    assets=cont_contracts,
    end_dt=pd.Timestamp('2018-10-31'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
        )

# %%
h.head()
# Out:
#                            ContinuousFuture(91554134238494720 [ED, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                            97.0586
# 2018-06-13 00:00:00+00:00                                            97.0437
# 2018-06-14 00:00:00+00:00                                            97.0536
# 2018-06-15 00:00:00+00:00                                            97.0685
# 2018-06-18 00:00:00+00:00                                            97.0735
#
#                            ContinuousFuture(95799348633337856 [TY, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                         119.282022
# 2018-06-13 00:00:00+00:00                                         119.063249
# 2018-06-14 00:00:00+00:00                                         119.312989
# 2018-06-15 00:00:00+00:00                                         119.468828
# 2018-06-18 00:00:00+00:00                                         119.468828
#
#                            ContinuousFuture(91855400424505344 [FV, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                         112.975687
# 2018-06-13 00:00:00+00:00                                         112.812038
# 2018-06-14 00:00:00+00:00                                         112.921803
# 2018-06-15 00:00:00+00:00                                         112.999636
# 2018-06-18 00:00:00+00:00                                         112.999636
#
#                            ContinuousFuture(95794950586826752 [TU, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                         105.710824
# 2018-06-13 00:00:00+00:00                                         105.624938
# 2018-06-14 00:00:00+00:00                                         105.648906
# 2018-06-15 00:00:00+00:00                                         105.679865
# 2018-06-18 00:00:00+00:00                                         105.694845
#
#                            ContinuousFuture(96074226540281856 [US, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                          142.16667
# 2018-06-13 00:00:00+00:00                                          141.85529
# 2018-06-14 00:00:00+00:00                                          142.53973
# 2018-06-15 00:00:00+00:00                                          142.91279
# 2018-06-18 00:00:00+00:00                                          142.81927
#
#                            ContinuousFuture(91837808238460928 [FF, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             97.815
# 2018-06-13 00:00:00+00:00                                             97.820
# 2018-06-14 00:00:00+00:00                                             97.815
# 2018-06-15 00:00:00+00:00                                             97.820
# 2018-06-18 00:00:00+00:00                                             97.820
#
#                            ContinuousFuture(96066529958887424 [UL, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                          156.87002
# 2018-06-13 00:00:00+00:00                                          156.55741
# 2018-06-14 00:00:00+00:00                                          157.52731
# 2018-06-15 00:00:00+00:00                                          158.06036
# 2018-06-18 00:00:00+00:00                                          157.84093
#
#                            ContinuousFuture(95491485377560576 [SA, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                          98.662065
# 2018-06-13 00:00:00+00:00                                          98.508704
# 2018-06-14 00:00:00+00:00                                          98.620146
# 2018-06-15 00:00:00+00:00                                          98.662065
# 2018-06-18 00:00:00+00:00                                          98.725454
#
#                            ContinuousFuture(94066518307962880 [N1U, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                          99.116276
# 2018-06-13 00:00:00+00:00                                          98.936734
# 2018-06-14 00:00:00+00:00                                          99.246757
# 2018-06-15 00:00:00+00:00                                          99.295817
# 2018-06-18 00:00:00+00:00                                          99.392895
#
#                            ContinuousFuture(92661342447665152 [I3, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             88.312
# 2018-06-13 00:00:00+00:00                                             88.062
# 2018-06-14 00:00:00+00:00                                             88.625
# 2018-06-15 00:00:00+00:00                                             89.312
# 2018-06-18 00:00:00+00:00                                             89.062
#
#                                                      ...                             \
# 2018-06-12 00:00:00+00:00                            ...
# 2018-06-13 00:00:00+00:00                            ...
# 2018-06-14 00:00:00+00:00                            ...
# 2018-06-15 00:00:00+00:00                            ...
# 2018-06-18 00:00:00+00:00                            ...
#
#                            ContinuousFuture(90721803936268288 [BO, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                              30.74
# 2018-06-13 00:00:00+00:00                                              30.77
# 2018-06-14 00:00:00+00:00                                              30.84
# 2018-06-15 00:00:00+00:00                                              30.18
# 2018-06-18 00:00:00+00:00                                              30.25
#
#                            ContinuousFuture(95504679517093888 [SM, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                              355.5
# 2018-06-13 00:00:00+00:00                                              349.6
# 2018-06-14 00:00:00+00:00                                              345.1
# 2018-06-15 00:00:00+00:00                                              340.8
# 2018-06-18 00:00:00+00:00                                              337.4
#
#                            ContinuousFuture(93523359563841536 [LC, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                            110.422
# 2018-06-13 00:00:00+00:00                                            109.998
# 2018-06-14 00:00:00+00:00                                            107.855
# 2018-06-15 00:00:00+00:00                                            110.925
# 2018-06-18 00:00:00+00:00                                            111.348
#
#                            ContinuousFuture(93263874819686400 [KW, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             597.29
# 2018-06-13 00:00:00+00:00                                             581.64
# 2018-06-14 00:00:00+00:00                                             563.57
# 2018-06-15 00:00:00+00:00                                             560.87
# 2018-06-18 00:00:00+00:00                                             539.02
#
#                            ContinuousFuture(93535454191747072 [LN, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             62.741
# 2018-06-13 00:00:00+00:00                                             63.762
# 2018-06-14 00:00:00+00:00                                             62.876
# 2018-06-15 00:00:00+00:00                                             62.953
# 2018-06-18 00:00:00+00:00                                             64.494
#
#                            ContinuousFuture(92115984680288256 [GC, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             1310.3
# 2018-06-13 00:00:00+00:00                                             1312.2
# 2018-06-14 00:00:00+00:00                                             1319.2
# 2018-06-15 00:00:00+00:00                                             1289.2
# 2018-06-18 00:00:00+00:00                                             1290.8
#
#                            ContinuousFuture(92401857703510016 [HG, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             3.3272
# 2018-06-13 00:00:00+00:00                                             3.3313
# 2018-06-14 00:00:00+00:00                                             3.2996
# 2018-06-15 00:00:00+00:00                                             3.2197
# 2018-06-18 00:00:00+00:00                                             3.1808
#
#                            ContinuousFuture(95500281470582784 [SI, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                             17.074
# 2018-06-13 00:00:00+00:00                                             17.175
# 2018-06-14 00:00:00+00:00                                             17.449
# 2018-06-15 00:00:00+00:00                                             16.658
# 2018-06-18 00:00:00+00:00                                             16.618
#
#                            ContinuousFuture(94659155075334144 [PL, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                                              909.2
# 2018-06-13 00:00:00+00:00                                              910.2
# 2018-06-14 00:00:00+00:00                                              918.7
# 2018-06-15 00:00:00+00:00                                              895.4
# 2018-06-18 00:00:00+00:00                                              891.5
#
#                            ContinuousFuture(94647060447428608 [PA, 0, volume, mul])
# 2018-06-12 00:00:00+00:00                                             1010.9
# 2018-06-13 00:00:00+00:00                                             1002.8
# 2018-06-14 00:00:00+00:00                                             1002.2
# 2018-06-15 00:00:00+00:00                                              977.5
# 2018-06-18 00:00:00+00:00                                              978.6
#
# [5 rows x 45 columns]

# %%
h.iloc[0]
# Out:
# ContinuousFuture(91554134238494720 [ED, 0, volume, mul])        97.058600
# ContinuousFuture(95799348633337856 [TY, 0, volume, mul])       119.282022
# ContinuousFuture(91855400424505344 [FV, 0, volume, mul])       112.975687
# ContinuousFuture(95794950586826752 [TU, 0, volume, mul])       105.710824
# ContinuousFuture(96074226540281856 [US, 0, volume, mul])       142.166670
# ContinuousFuture(91837808238460928 [FF, 0, volume, mul])        97.815000
# ContinuousFuture(96066529958887424 [UL, 0, volume, mul])       156.870020
# ContinuousFuture(95491485377560576 [SA, 0, volume, mul])        98.662065
# ContinuousFuture(94066518307962880 [N1U, 0, volume, mul])       99.116276
# ContinuousFuture(92661342447665152 [I3, 0, volume, mul])        88.312000
# ContinuousFuture(91570626912911360 [ES, 0, volume, mul])      2793.290000
# ContinuousFuture(94101702680051712 [NQ, 0, volume, mul])      7253.790000
# ContinuousFuture(97193529377357824 [YM, 0, volume, mul])     25341.100000
# ContinuousFuture(93805934052179968 [MD, 0, volume, mul])      2014.500000
# ContinuousFuture(94095105610285056 [NK, 0, volume, mul])     22700.900000
# ContinuousFuture(96898860261113856 [XAF, 0, volume, mul])     1123.600000
# ContinuousFuture(96898860261113856 [XAK, 0, volume, mul])     1123.600000
# ContinuousFuture(96898860261113856 [XAP, 0, volume, mul])     1123.600000
# ContinuousFuture(96898860261113856 [XAU, 0, volume, mul])     1123.600000
# ContinuousFuture(96898860261113856 [XAY, 0, volume, mul])     1123.600000
# ContinuousFuture(90999980378095616 [CL, 0, volume, mul])        64.350000
# ContinuousFuture(94090707563773952 [NG, 0, volume, mul])         2.955000
# ContinuousFuture(95211109912477696 [RB, 0, volume, mul])         1.924600
# ContinuousFuture(92410653796532224 [HO, 0, volume, mul])         2.175200
# ContinuousFuture(90733898564173824 [BZ, 0, volume, mul])        75.940000
# ContinuousFuture(91553034726866944 [EC, 0, volume, mul])         1.188210
# ContinuousFuture(92984598866231296 [JY, 0, volume, mul])      9182.900000
# ContinuousFuture(90722903447896064 [BP, 0, volume, mul])         1.347200
# ContinuousFuture(90428234331652096 [AD, 0, volume, mul])         0.758000
# ContinuousFuture(90991184285073408 [CD, 0, volume, mul])         0.770020
# ContinuousFuture(93819128191713280 [MP, 0, volume, mul])     45560.300000
# ContinuousFuture(95496982935699456 [SF, 0, volume, mul])         1.030000
# ContinuousFuture(98871384121344000 [_C, 0, volume, mul])       399.720000
# ContinuousFuture(98888976307388416 [_S, 0, volume, mul])       976.750000
# ContinuousFuture(98893374353899520 [_W, 0, volume, mul])       567.030000
# ContinuousFuture(90721803936268288 [BO, 0, volume, mul])        30.740000
# ContinuousFuture(95504679517093888 [SM, 0, volume, mul])       355.500000
# ContinuousFuture(93523359563841536 [LC, 0, volume, mul])       110.422000
# ContinuousFuture(93263874819686400 [KW, 0, volume, mul])       597.290000
# ContinuousFuture(93535454191747072 [LN, 0, volume, mul])        62.741000
# ContinuousFuture(92115984680288256 [GC, 0, volume, mul])      1310.300000
# ContinuousFuture(92401857703510016 [HG, 0, volume, mul])         3.327200
# ContinuousFuture(95500281470582784 [SI, 0, volume, mul])        17.074000
# ContinuousFuture(94659155075334144 [PL, 0, volume, mul])       909.200000
# ContinuousFuture(94647060447428608 [PA, 0, volume, mul])      1010.900000
# Name: 2018-06-12 00:00:00+00:00, dtype: float64

# %%
long_names = [
    'XAF',# e-mini financial sector
    'XAK',# e-mini technology sector
    'XAP',# e-mini consumer staples sector
    'XAU',# e-mini utilities sector
    'XAY',# e-mini consumer discretionary sector',
]

# %%
long_cont = [continuous_future(contract,
                                offset=0,
                                adjustment='mul',
                                roll_style='volume')
            for contract in long_names]

# %%
long_cont_his = history(
                        assets=long_cont,
                        end_dt=pd.Timestamp('2018-10-31'),
                        bar_count=100,
                        frequency='1d',
                        field='sid',
                        data_frequency='daily'
                        )

# %%
long_cont_his.applymap(lambda x: bundle_data.asset_finder.retrieve_asset(x))
# Out:
#                           ContinuousFuture(96898860261113856 [XAF, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                             Future(26358 [XAYM18])
# 2018-06-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-14 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-15 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-21 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-22 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-25 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-26 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-27 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-28 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-29 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-02 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-03 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-05 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-06 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-09 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-10 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-11 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-12 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-16 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-17 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-23 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-24 00:00:00+00:00                             Future(27061 [XAYU18])
# ...                                                                      ...
# 2018-09-20 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-21 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-27 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-28 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-01 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-02 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-03 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-04 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-05 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-08 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-09 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-10 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-11 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-12 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-15 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-16 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-17 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-18 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-19 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-22 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-23 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-29 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-30 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-31 00:00:00+00:00                             Future(27803 [XAYZ18])
#
#                           ContinuousFuture(96898860261113856 [XAK, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                             Future(26358 [XAYM18])
# 2018-06-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-14 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-15 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-21 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-22 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-25 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-26 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-27 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-28 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-29 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-02 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-03 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-05 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-06 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-09 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-10 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-11 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-12 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-16 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-17 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-23 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-24 00:00:00+00:00                             Future(27061 [XAYU18])
# ...                                                                      ...
# 2018-09-20 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-21 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-27 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-28 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-01 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-02 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-03 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-04 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-05 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-08 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-09 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-10 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-11 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-12 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-15 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-16 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-17 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-18 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-19 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-22 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-23 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-29 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-30 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-31 00:00:00+00:00                             Future(27803 [XAYZ18])
#
#                           ContinuousFuture(96898860261113856 [XAP, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                             Future(26358 [XAYM18])
# 2018-06-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-14 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-15 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-21 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-22 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-25 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-26 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-27 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-28 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-29 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-02 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-03 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-05 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-06 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-09 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-10 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-11 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-12 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-16 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-17 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-23 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-24 00:00:00+00:00                             Future(27061 [XAYU18])
# ...                                                                      ...
# 2018-09-20 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-21 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-27 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-28 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-01 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-02 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-03 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-04 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-05 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-08 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-09 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-10 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-11 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-12 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-15 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-16 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-17 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-18 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-19 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-22 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-23 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-29 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-30 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-31 00:00:00+00:00                             Future(27803 [XAYZ18])
#
#                           ContinuousFuture(96898860261113856 [XAU, 0, volume, mul])  \
# 2018-06-12 00:00:00+00:00                             Future(26358 [XAYM18])
# 2018-06-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-14 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-15 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-21 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-22 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-25 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-26 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-27 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-28 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-29 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-02 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-03 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-05 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-06 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-09 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-10 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-11 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-12 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-16 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-17 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-23 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-24 00:00:00+00:00                             Future(27061 [XAYU18])
# ...                                                                      ...
# 2018-09-20 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-21 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-27 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-28 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-01 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-02 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-03 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-04 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-05 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-08 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-09 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-10 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-11 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-12 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-15 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-16 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-17 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-18 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-19 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-22 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-23 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-29 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-30 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-31 00:00:00+00:00                             Future(27803 [XAYZ18])
#
#                           ContinuousFuture(96898860261113856 [XAY, 0, volume, mul])
# 2018-06-12 00:00:00+00:00                             Future(26358 [XAYM18])
# 2018-06-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-14 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-15 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-21 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-22 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-25 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-26 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-27 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-28 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-06-29 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-02 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-03 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-05 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-06 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-09 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-10 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-11 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-12 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-13 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-16 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-17 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-18 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-19 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-20 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-23 00:00:00+00:00                             Future(27061 [XAYU18])
# 2018-07-24 00:00:00+00:00                             Future(27061 [XAYU18])
# ...                                                                      ...
# 2018-09-20 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-21 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-27 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-09-28 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-01 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-02 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-03 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-04 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-05 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-08 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-09 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-10 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-11 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-12 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-15 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-16 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-17 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-18 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-19 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-22 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-23 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-24 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-25 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-26 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-29 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-30 00:00:00+00:00                             Future(27803 [XAYZ18])
# 2018-10-31 00:00:00+00:00                             Future(27803 [XAYZ18])
#
# [100 rows x 5 columns]

# %%
long_cont_his.columns.map(lambda x: x.root_symbol)
# Out:
# array(['XAF', 'XAK', 'XAP', 'XAU', 'XAY'], dtype=object)

# %%
dir(long_cont[1])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_kwargnames',
#  'adjustment',
#  'end_date',
#  'exchange',
#  'from_dict',
#  'is_alive_for_session',
#  'is_exchange_open',
#  'offset',
#  'roll_style',
#  'root_symbol',
#  'sid',
#  'start_date',
#  'to_dict']

# %%
a = pd.read_csv('C:/Users/tomek/zipline/debug/CMEGroup.csv', header=None)

# %%
roots = a[0]
roots = roots.tolist()
roots=[r if len(r) > 1 else '_' + r for r in roots]
roots

# %%
len(roots)

# %%
continuous_roots = [continuous_future(r, offset=0, adjustment='add', roll_style='volume') for r in roots]

# %%
h = history(
    assets=continuous_roots,
    end_dt=pd.Timestamp('2018-10-31'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
        )

# %%
h.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-da8b60ec2fad> in <module>()
# ----> 1 h.head()
#
# NameError: name 'h' is not defined

# %%
jy_contracts = []
for x in ['{}{}{}'.format('GC', l, y)  for y in range(23) for l in 'FGHJKMNQUVXZ']:
    try:
        jy_contracts.append(bundle_data.asset_finder.lookup_future_symbol(x))
    except:
        pass

# %%
jy_contracts
# Out:
# [Future(341 [GCF10]),
#  Future(342 [GCG10]),
#  Future(344 [GCH10]),
#  Future(345 [GCJ10]),
#  Future(346 [GCK10]),
#  Future(348 [GCM10]),
#  Future(349 [GCN10]),
#  Future(350 [GCQ10]),
#  Future(352 [GCU10]),
#  Future(353 [GCV10]),
#  Future(354 [GCX10]),
#  Future(356 [GCZ10]),
#  Future(357 [GCF11]),
#  Future(358 [GCG11]),
#  Future(360 [GCH11]),
#  Future(361 [GCJ11]),
#  Future(362 [GCK11]),
#  Future(364 [GCM11]),
#  Future(365 [GCN11]),
#  Future(366 [GCQ11]),
#  Future(368 [GCU11]),
#  Future(369 [GCV11]),
#  Future(370 [GCX11]),
#  Future(372 [GCZ11]),
#  Future(373 [GCF12]),
#  Future(374 [GCG12]),
#  Future(376 [GCH12]),
#  Future(377 [GCJ12]),
#  Future(378 [GCK12]),
#  Future(380 [GCM12]),
#  Future(381 [GCN12]),
#  Future(382 [GCQ12]),
#  Future(384 [GCU12]),
#  Future(385 [GCV12]),
#  Future(386 [GCX12]),
#  Future(388 [GCZ12]),
#  Future(389 [GCF13]),
#  Future(390 [GCG13]),
#  Future(392 [GCH13]),
#  Future(393 [GCJ13]),
#  Future(394 [GCK13]),
#  Future(396 [GCM13]),
#  Future(397 [GCN13]),
#  Future(398 [GCQ13]),
#  Future(400 [GCU13]),
#  Future(401 [GCV13]),
#  Future(402 [GCX13]),
#  Future(404 [GCZ13]),
#  Future(405 [GCF14]),
#  Future(406 [GCG14]),
#  Future(408 [GCH14]),
#  Future(409 [GCJ14]),
#  Future(410 [GCK14]),
#  Future(412 [GCM14]),
#  Future(413 [GCN14]),
#  Future(414 [GCQ14]),
#  Future(416 [GCU14]),
#  Future(417 [GCV14]),
#  Future(418 [GCX14]),
#  Future(420 [GCZ14]),
#  Future(421 [GCF15]),
#  Future(422 [GCG15]),
#  Future(424 [GCH15]),
#  Future(425 [GCJ15]),
#  Future(426 [GCK15]),
#  Future(428 [GCM15]),
#  Future(429 [GCN15]),
#  Future(430 [GCQ15]),
#  Future(432 [GCU15]),
#  Future(433 [GCV15]),
#  Future(434 [GCX15]),
#  Future(436 [GCZ15]),
#  Future(437 [GCF16]),
#  Future(438 [GCG16]),
#  Future(440 [GCH16]),
#  Future(441 [GCJ16]),
#  Future(442 [GCK16]),
#  Future(444 [GCM16]),
#  Future(445 [GCN16]),
#  Future(446 [GCQ16]),
#  Future(448 [GCU16]),
#  Future(449 [GCV16]),
#  Future(450 [GCX16]),
#  Future(452 [GCZ16]),
#  Future(453 [GCF17]),
#  Future(454 [GCG17]),
#  Future(456 [GCH17]),
#  Future(457 [GCJ17]),
#  Future(458 [GCK17]),
#  Future(460 [GCM17]),
#  Future(461 [GCN17]),
#  Future(462 [GCQ17]),
#  Future(464 [GCU17]),
#  Future(465 [GCV17]),
#  Future(466 [GCX17]),
#  Future(468 [GCZ17]),
#  Future(469 [GCF18]),
#  Future(470 [GCG18]),
#  Future(472 [GCH18]),
#  Future(473 [GCJ18]),
#  Future(474 [GCK18]),
#  Future(476 [GCM18]),
#  Future(477 [GCN18]),
#  Future(478 [GCQ18]),
#  Future(480 [GCU18]),
#  Future(481 [GCV18]),
#  Future(482 [GCX18]),
#  Future(484 [GCZ18]),
#  Future(485 [GCF19]),
#  Future(486 [GCG19]),
#  Future(488 [GCJ19]),
#  Future(490 [GCM19]),
#  Future(491 [GCQ19]),
#  Future(493 [GCV19]),
#  Future(495 [GCZ19]),
#  Future(496 [GCG20]),
#  Future(497 [GCJ20]),
#  Future(498 [GCM20]),
#  Future(499 [GCQ20]),
#  Future(500 [GCZ20]),
#  Future(501 [GCM21]),
#  Future(502 [GCZ21]),
#  Future(503 [GCM22]),
#  Future(504 [GCZ22])]

# %%
jy_dates = [(x.symbol, x.start_date, x.end_date) for x in jy_contracts]

# %%
jy_dates
# Out:
# [('JYH10',
#   Timestamp('2008-09-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM10',
#   Timestamp('2008-12-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU10',
#   Timestamp('2009-03-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-09-13 00:00:00+0000', tz='UTC')),
#  ('JYZ10',
#   Timestamp('2009-06-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2010-12-13 00:00:00+0000', tz='UTC')),
#  ('JYH11',
#   Timestamp('2009-09-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-03-15 00:00:00+0000', tz='UTC')),
#  ('JYM11',
#   Timestamp('2009-12-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-06-14 00:00:00+0000', tz='UTC')),
#  ('JYU11',
#   Timestamp('2010-03-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-09-20 00:00:00+0000', tz='UTC')),
#  ('JYZ11',
#   Timestamp('2010-06-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2011-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH12',
#   Timestamp('2010-09-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-03-19 00:00:00+0000', tz='UTC')),
#  ('JYM12',
#   Timestamp('2010-12-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-06-18 00:00:00+0000', tz='UTC')),
#  ('JYU12',
#   Timestamp('2011-03-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-09-17 00:00:00+0000', tz='UTC')),
#  ('JYZ12',
#   Timestamp('2011-06-13 00:00:00+0000', tz='UTC'),
#   Timestamp('2012-12-17 00:00:00+0000', tz='UTC')),
#  ('JYH13',
#   Timestamp('2011-10-03 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-03-18 00:00:00+0000', tz='UTC')),
#  ('JYM13',
#   Timestamp('2011-12-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-06-17 00:00:00+0000', tz='UTC')),
#  ('JYU13',
#   Timestamp('2012-03-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-09-16 00:00:00+0000', tz='UTC')),
#  ('JYZ13',
#   Timestamp('2012-06-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2013-12-16 00:00:00+0000', tz='UTC')),
#  ('JYH14',
#   Timestamp('2012-09-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-03-17 00:00:00+0000', tz='UTC')),
#  ('JYM14',
#   Timestamp('2012-12-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-06-16 00:00:00+0000', tz='UTC')),
#  ('JYU14',
#   Timestamp('2013-03-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-09-15 00:00:00+0000', tz='UTC')),
#  ('JYZ14',
#   Timestamp('2013-06-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2014-12-15 00:00:00+0000', tz='UTC')),
#  ('JYH15',
#   Timestamp('2013-08-09 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-03-16 00:00:00+0000', tz='UTC')),
#  ('JYM15',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-06-15 00:00:00+0000', tz='UTC')),
#  ('JYU15',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-09-14 00:00:00+0000', tz='UTC')),
#  ('JYZ15',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2015-12-14 00:00:00+0000', tz='UTC')),
#  ('JYH16',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-03-14 00:00:00+0000', tz='UTC')),
#  ('JYM16',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-06-13 00:00:00+0000', tz='UTC')),
#  ('JYU16',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-09-19 00:00:00+0000', tz='UTC')),
#  ('JYZ16',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2016-12-19 00:00:00+0000', tz='UTC')),
#  ('JYH17',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-03-13 00:00:00+0000', tz='UTC')),
#  ('JYJ17',
#   Timestamp('2017-02-27 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-04-17 00:00:00+0000', tz='UTC')),
#  ('JYK17',
#   Timestamp('2017-02-27 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-05-15 00:00:00+0000', tz='UTC')),
#  ('JYM17',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-06-19 00:00:00+0000', tz='UTC')),
#  ('JYN17',
#   Timestamp('2017-02-27 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-07-17 00:00:00+0000', tz='UTC')),
#  ('JYQ17',
#   Timestamp('2017-04-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-08-14 00:00:00+0000', tz='UTC')),
#  ('JYU17',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-09-18 00:00:00+0000', tz='UTC')),
#  ('JYV17',
#   Timestamp('2017-05-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-10-16 00:00:00+0000', tz='UTC')),
#  ('JYX17',
#   Timestamp('2017-07-18 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-11-13 00:00:00+0000', tz='UTC')),
#  ('JYZ17',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2017-12-18 00:00:00+0000', tz='UTC')),
#  ('JYF18',
#   Timestamp('2017-08-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-01-12 00:00:00+0000', tz='UTC')),
#  ('JYG18',
#   Timestamp('2017-10-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-02-16 00:00:00+0000', tz='UTC')),
#  ('JYH18',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-03-19 00:00:00+0000', tz='UTC')),
#  ('JYJ18',
#   Timestamp('2017-11-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-04-16 00:00:00+0000', tz='UTC')),
#  ('JYK18',
#   Timestamp('2018-01-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-05-14 00:00:00+0000', tz='UTC')),
#  ('JYM18',
#   Timestamp('2013-08-12 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-06-18 00:00:00+0000', tz='UTC')),
#  ('JYN18',
#   Timestamp('2018-02-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-07-16 00:00:00+0000', tz='UTC')),
#  ('JYQ18',
#   Timestamp('2018-04-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-08-13 00:00:00+0000', tz='UTC')),
#  ('JYU18',
#   Timestamp('2013-09-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-09-17 00:00:00+0000', tz='UTC')),
#  ('JYV18',
#   Timestamp('2018-05-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-10-15 00:00:00+0000', tz='UTC')),
#  ('JYX18',
#   Timestamp('2018-07-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYZ18',
#   Timestamp('2014-02-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYF19',
#   Timestamp('2018-08-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYG19',
#   Timestamp('2018-10-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYH19',
#   Timestamp('2014-03-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYM19',
#   Timestamp('2014-06-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYU19',
#   Timestamp('2014-09-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYZ19',
#   Timestamp('2014-12-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYH20',
#   Timestamp('2015-03-17 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYM20',
#   Timestamp('2015-06-16 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYU20',
#   Timestamp('2015-09-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYZ20',
#   Timestamp('2015-12-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYH21',
#   Timestamp('2016-03-15 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYM21',
#   Timestamp('2016-06-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYU21',
#   Timestamp('2016-09-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYZ21',
#   Timestamp('2016-12-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYH22',
#   Timestamp('2017-03-14 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYM22',
#   Timestamp('2017-06-20 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYU22',
#   Timestamp('2017-09-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC')),
#  ('JYZ22',
#   Timestamp('2017-12-19 00:00:00+0000', tz='UTC'),
#   Timestamp('2018-11-06 00:00:00+0000', tz='UTC'))]

# %%
sid = bundle_data.asset_finder.lookup_future_symbol('GCZ00').sid
start_dt = pd.Timestamp('2000-12-1', tz='UTC', offset='C')
oc = bundle_data.asset_finder.get_ordered_contracts('GC')
chain = oc.active_chain(sid, start_dt.value)
all_chain = bundle_data.asset_finder.retrieve_all(chain)
all_chain
# Out:
# [Future(5551 [GCZ00]),
#  Future(5580 [GCG01]),
#  Future(5634 [GCJ01]),
#  Future(5687 [GCM01]),
#  Future(5723 [GCQ01]),
#  Future(5781 [GCV01]),
#  Future(5836 [GCZ01]),
#  Future(5864 [GCG02]),
#  Future(5923 [GCJ02]),
#  Future(5975 [GCM02]),
#  Future(6009 [GCQ02]),
#  Future(6069 [GCV02]),
#  Future(6120 [GCZ02]),
#  Future(6258 [GCM03]),
#  Future(6402 [GCZ03]),
#  Future(6538 [GCM04]),
#  Future(6683 [GCZ04]),
#  Future(6820 [GCM05])]

# %%
c = continuous_future('I3', offset=0, roll_style='volume', adjustment='mul')

# %%
c.start_date
# Out:
# Timestamp('2012-10-30 00:00:00+0000', tz='UTC')

# %%
h = history(
    assets=[c],
    end_dt=pd.Timestamp('2013-04-30'),
    bar_count=100,
    frequency='1d',
    field='price',
    data_frequency='daily'
        )

# %%
h
# Out:
#                            ContinuousFuture(92661342447665152 [I3, 0, volume, mul])
# 2012-12-05 00:00:00+00:00                                          130.18641
# 2012-12-06 00:00:00+00:00                                          130.29540
# 2012-12-07 00:00:00+00:00                                          130.29540
# 2012-12-10 00:00:00+00:00                                          130.29540
# 2012-12-11 00:00:00+00:00                                          130.29540
# 2012-12-12 00:00:00+00:00                                          130.29540
# 2012-12-13 00:00:00+00:00                                          130.29540
# 2012-12-14 00:00:00+00:00                                          130.29540
# 2012-12-17 00:00:00+00:00                                          127.38977
# 2012-12-18 00:00:00+00:00                                          123.34328
# 2012-12-19 00:00:00+00:00                                          124.03019
# 2012-12-20 00:00:00+00:00                                          123.92121
# 2012-12-21 00:00:00+00:00                                          124.99907
# 2012-12-24 00:00:00+00:00                                          124.68711
# 2012-12-26 00:00:00+00:00                                          124.68711
# 2012-12-27 00:00:00+00:00                                          125.53000
# 2012-12-28 00:00:00+00:00                                          125.53000
# 2012-12-31 00:00:00+00:00                                          124.48414
# 2013-01-02 00:00:00+00:00                                          122.03045
# 2013-01-03 00:00:00+00:00                                          121.35953
# 2013-01-04 00:00:00+00:00                                          121.49952
# 2013-01-07 00:00:00+00:00                                          121.54651
# 2013-01-08 00:00:00+00:00                                          122.14043
# 2013-01-09 00:00:00+00:00                                          122.45239
# 2013-01-10 00:00:00+00:00                                          121.90546
# 2013-01-11 00:00:00+00:00                                          122.18743
# 2013-01-14 00:00:00+00:00                                          122.65537
# 2013-01-15 00:00:00+00:00                                          123.17130
# 2013-01-16 00:00:00+00:00                                          123.28029
# 2013-01-17 00:00:00+00:00                                          121.99945
# ...                                                                      ...
# 2013-03-19 00:00:00+00:00                                          118.79600
# 2013-03-20 00:00:00+00:00                                          118.04600
# 2013-03-21 00:00:00+00:00                                          118.26500
# 2013-03-22 00:00:00+00:00                                          118.26500
# 2013-03-25 00:00:00+00:00                                          118.26500
# 2013-03-26 00:00:00+00:00                                          118.26500
# 2013-03-27 00:00:00+00:00                                          119.32800
# 2013-03-28 00:00:00+00:00                                          119.18700
# 2013-04-01 00:00:00+00:00                                          119.46800
# 2013-04-02 00:00:00+00:00                                          119.31200
# 2013-04-03 00:00:00+00:00                                          120.09300
# 2013-04-04 00:00:00+00:00                                          121.31200
# 2013-04-05 00:00:00+00:00                                          124.34300
# 2013-04-08 00:00:00+00:00                                          122.62500
# 2013-04-09 00:00:00+00:00                                          121.96800
# 2013-04-10 00:00:00+00:00                                          120.48400
# 2013-04-11 00:00:00+00:00                                          120.62500
# 2013-04-12 00:00:00+00:00                                          120.62500
# 2013-04-15 00:00:00+00:00                                          123.28100
# 2013-04-16 00:00:00+00:00                                          122.89000
# 2013-04-17 00:00:00+00:00                                          123.65600
# 2013-04-18 00:00:00+00:00                                          124.03100
# 2013-04-19 00:00:00+00:00                                          123.82800
# 2013-04-22 00:00:00+00:00                                          123.64000
# 2013-04-23 00:00:00+00:00                                          123.20300
# 2013-04-24 00:00:00+00:00                                          123.21800
# 2013-04-25 00:00:00+00:00                                          122.78100
# 2013-04-26 00:00:00+00:00                                          123.81200
# 2013-04-29 00:00:00+00:00                                          124.03100
# 2013-04-30 00:00:00+00:00                                          123.57800
#
# [100 rows x 1 columns]
