# %%
import pandas as pd

# %%
f = pd.read_excel('C:/Users/tomek/Downloads/product-calendar (9).xls', header=3)

# %%
f.head()
# Out:
#                        Contract Month Product Code First Trade  Last Trade  \
# 0  November 2018 Japanese Yen Futures        J1X18  2018-07-17  2018-11-19
# 1  December 2018 Japanese Yen Futures        J1Z18  2013-12-17  2018-12-17
# 2   January 2019 Japanese Yen Futures        J1F19  2018-08-14  2019-01-14
# 3  February 2019 Japanese Yen Futures        J1G19  2018-10-16  2019-02-15
# 4     March 2019 Japanese Yen Futures        J1H19  2014-03-18  2019-03-18
#
#    Settlement First Holding Last Holding First Position Last Position  \
# 0  2018-11-19             -            -     2018-11-19    2018-11-19
# 1  2018-12-17             -            -     2018-12-17    2018-12-17
# 2  2019-01-14             -            -     2019-01-14    2019-01-14
# 3  2019-02-15             -            -     2019-02-15    2019-02-15
# 4  2019-03-18             -            -     2019-03-18    2019-03-18
#
#   First Notice Last Notice First Delivery Last Delivery
# ...

# %%
root = 'JY'
f['Product Code'] = f['Product Code'].apply(lambda x: root + x[-3:])

# %%
f.head()
# Out:
#                        Contract Month Product Code First Trade  Last Trade  \
# 0  November 2018 Japanese Yen Futures        JYX18  2018-07-17  2018-11-19
# 1  December 2018 Japanese Yen Futures        JYZ18  2013-12-17  2018-12-17
# 2   January 2019 Japanese Yen Futures        JYF19  2018-08-14  2019-01-14
# 3  February 2019 Japanese Yen Futures        JYG19  2018-10-16  2019-02-15
# 4     March 2019 Japanese Yen Futures        JYH19  2014-03-18  2019-03-18
#
#    Settlement First Holding Last Holding First Position Last Position  \
# 0  2018-11-19             -            -     2018-11-19    2018-11-19
# 1  2018-12-17             -            -     2018-12-17    2018-12-17
# 2  2019-01-14             -            -     2019-01-14    2019-01-14
# 3  2019-02-15             -            -     2019-02-15    2019-02-15
# 4  2019-03-18             -            -     2019-03-18    2019-03-18
#
#   First Notice Last Notice First Delivery Last Delivery
# ...
