# %%
# %load_ext zipline

# %%
# %%zipline --start 2018-1-2 --end 2018-1-25 -b futures -o quick.pickle
#
# import pandas as pd
# import numpy as np
# import talib
# from zipline.api import (order, record, symbol, continuous_future,
#                          future_symbol, get_open_orders, order_target_percent,
#                          set_slippage, set_commission)
# from zipline.finance.slippage import FixedSlippage
# from zipline.finance.commission import PerTrade
# from contracts import contracts
# import sys
#
# FAST_MA = 50
# SLOW_MA = 100
# BREAKOUT = 50 # breakout beyond x days max/min
# STOP = 2 # stop after x ATRs
# RISK = .2 # % of capital daily risk per position
#
#
# def initialize(context):
#     set_slippage(us_futures=FixedSlippage(spread=0.0))
#     set_commission(us_futures=PerTrade(0))
#     context.contracts = [
#         continuous_future(contract,
#                           offset=0,
#                           adjustment='mul',
#                           roll='volume')
#         for contract in contracts]
#
#     context.min_max = {}
#     context.COUNTER = 0
#
#
#
# def handle_data(context, data):
#     hist = data.history(context.contracts,
#                         fields = ['price', 'high', 'low'],
#                         bar_count = SLOW_MA + 10,
#                         frequency = '1d')
#     #print(hist.head())
#
#
#     slow_ma = hist['price'].apply(lambda x:
#                                   talib.EMA(x.as_matrix(),
#                                             timeperiod=SLOW_MA)[-1])
#     fast_ma = hist['price'].apply(lambda x:
#                                   talib.EMA(x.as_matrix(),
#                                             timeperiod=FAST_MA)[-1])
#     atr = hist.apply(lambda x: talib.ATR(x['high'].fillna(x['price']).as_matrix(),
#                                          x['low'].fillna(x['price']).as_matrix(),
#                                          x['price'].as_matrix(),
#                                          timeperiod=SLOW_MA)[-1],
#                      axis=(1,0))
#     #print('slow ma')
#     #print(slow_ma)
#     #print('fast ma')
#     #print(fast_ma)
#     #print('atr')
#     #print(atr)
#     # breakout above is a buy signal
#     upper = hist['price'][-BREAKOUT-1:-2].max(axis=0)
#     #print('upper')
#     #print(upper)
#     # breakout below is a sell signal
#     lower = hist['price'][-BREAKOUT-1:-2].min(axis=0)
#     #print('lower')
#     #print(lower)
#     # last price
#     price = hist['price'].iloc[-1,:]
#     #print('price')
#     #print(price)
#
#     #weights = price * context.risk_factor * context.weights
#     #weights = (RISK * context.weights * price) / (atr *100)
#
#     weights = RISK * price / (atr * 100)
#     #print('weights')
#     #print(weights)
#
#     longs = ((price > upper) & (fast_ma > slow_ma)) * weights
#     shorts = ((price < lower) & (fast_ma < slow_ma)) * -weights
#
#
#     positions = longs + shorts
#
#
#
#     # Get the current contract of each of the futures.
#     contracts = data.current(context.contracts, 'contract')
#     #print('contracts')
#     #print(contracts)
#
#
#     positions.index = data.current(positions.index, 'contract')
#     atr.index = data.current(atr.index, 'contract')
#     price.index = data.current(price.index, 'contract')
#     atr_dict = atr.to_dict()
#     #price = data.current(atr.index, 'price')
#     #print('positions')
#     #print(positions)
#     #print(atr)
#     #print(price)
#     #print(atr_dict)
#     #print('positions type:')
#     #print(type(positions))
#     positions = positions[positions != 0]
#     #print('positions')
#     #print(positions)
#
#     # rollover expiring contracts
#     for cont, pos in context.portfolio.positions.items():
#         if cont not in contracts:
#             weight = context.portfolio.current_portfolio_weights[cont]
#             root = cont.root_symbol
#             # close existing contract
#             positions[cont] = 0
#             current = data.current(continuous_future(root), 'contract')
#             # open current contract
#             positions[current] = weight
#             # still need the old contract for stop-loss calculation
#             atr_dict[cont] = atr_dict[current]
#
#
#
#     # implement stop-loss
#     stop_out = []
#     for contract, position in context.portfolio.positions.items():
#         if contract in context.min_max:
#             context.min_max[contract] = (min(context.min_max[contract][0],
#                                              position.cost_basis,
#                                              position.last_sale_price),
#                                          max(context.min_max[contract][1],
#                                              position.cost_basis,
#                                              position.last_sale_price))
#         else:
#           context.min_max[contract] = (min(position.cost_basis,
#                                            position.last_sale_price),
#                                        max(position.cost_basis,
#                                            position.last_sale_price))
#
#         # calculate stop loss level
#         try:
#             if position.amount > 0:
#                 stop_price = context.min_max[contract][1] - atr_dict[contract] * STOP
#                 if price[contract] <= stop_price:
#                     positions[contract] = 0
#                     stop_out.append(contract)
#
#             if position.amount < 0:
#                 stop_price = context.min_max[contract][0] + atr_dict[contract] * STOP
#                 if price[contract] >= stop_price:
#                     positions[contract] = 0
#                     stop_out.append(contract)
#         except (KeyError, IndexError):
#             pass
#             #print('key error in stop-loss function: ', contract)
#             #print(context.min_max)
#             #print(atr_dict)
#
#     temp = []
#     for key in context.min_max.keys():
#         if key not in context.portfolio.positions.keys():
#             temp.append(key)
#     for key in temp:
#         del context.min_max[key]
#
#     # list of positions not to be affected by stop-loss
#     current_positions = list(context.portfolio.positions.keys())
#     for pos in stop_out:
#         if pos in current_positions:
#             current_positions.remove(pos)
#     #print('current positions')
#     #print(current_positions)
#
#     # fillna is a temporary fix
#     weights_dict = positions.fillna(0).to_dict()
#     #print(weights_dict)
#     #print('orders:')
#     for asset, target in weights_dict.items():
#         if target not in current_positions:
#             print(asset, target)
#             order_target_percent(asset, target)
#
#
#     print('portfolio:')
#     print(context.portfolio)
#     print('positions:')
#     print(context.portfolio.positions)
#     context.COUNTER += 1
#     if context.COUNTER > 2:
#         sys.exit()
# Out:
# Future(25376 [FFF18]) -15.4908343461
# Future(25760 [PAH18]) 0.116600836102
# Future(25366 [BZH18]) 0.109267579167
# Future(25303 [CLG18]) 0.106322982054
# Future(25737 [BPH18]) 0.264496681176
# Future(25354 [HOG18]) 0.103496780923
# Future(25789 [TUH18]) -3.08303002833
# Future(25711 [MDH18]) 0.253777926301
# portfolio:
# Portfolio({'portfolio_value': 10000000.0, 'pnl': 0.0, 'positions': {}, 'starting_cash': 10000000.0, 'cash_flow': 0.0, 'cash': 10000000.0, 'returns': 0.0, 'start_date': Timestamp('2018-01-02 00:00:00+0000', tz='UTC', offset='C'), 'positions_value': 0.0, 'positions_exposure': 0.0})
# positions:
# {}
# Future(25376 [FFF18]) -15.488084781
# Future(25760 [PAH18]) 0.108335
# Future(25737 [BPH18]) 0.2623375
# Future(25354 [HOG18]) 0.0964656
# Future(25687 [NKH18]) 0.181410196748
# Future(25708 [ESH18]) 0.343656284914
# Future(25710 [YMH18]) 0.350124716501
# Future(25711 [MDH18]) 0.250172
# Future(25715 [NQH18]) 0.214484090462
# Future(25366 [BZH18]) 0.108544
# Future(25303 [CLG18]) 0.104771
# Future(25789 [TUH18]) -3.0806784
# portfolio:
# Portfolio({'portfolio_value': 10000000.0, 'pnl': 0.0, 'positions': {Future(25376 [FFF18]): Position({'amount': -377, 'last_sale_price': 98.59, 'asset': Future(25376 [FFF18]), 'cost_basis': 98.59, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25760 [PAH18]): Position({'amount': 10, 'last_sale_price': 1083.35, 'asset': Future(25760 [PAH18]), 'cost_basis': 1083.35, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25366 [BZH18]): Position({'amount': 16, 'last_sale_price': 67.84, 'asset': Future(25366 [BZH18]), 'cost_basis': 67.84, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25303 [CLG18]): Position({'amount': 17, 'last_sale_price': 61.63, 'asset': Future(25303 [CLG18]), 'cost_basis': 61.63, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25737 [BPH18]): Position({'amount': 31, 'last_sale_price': 1.354, 'asset': Future(25737 [BPH18]), 'cost_basis': 1.354, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25354 [HOG18]): Position({'amount': 11, 'last_sale_price': 2.088, 'asset': Future(25354 [HOG18]), 'cost_basis': 2.088, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25789 [TUH18]): Position({'amount': -144, 'last_sale_price': 106.968, 'asset': Future(25789 [TUH18]), 'cost_basis': 106.968, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25711 [MDH18]): Position({'amount': 13, 'last_sale_price': 1924.4, 'asset': Future(25711 [MDH18]), 'cost_basis': 1924.4, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')})}, 'starting_cash': 10000000.0, 'cash_flow': 0.0, 'cash': 10000000.0, 'returns': 0.0, 'start_date': Timestamp('2018-01-02 00:00:00+0000', tz='UTC', offset='C'), 'positions_value': 0.0, 'positions_exposure': -176381380.81})
# positions:
# {Future(25376 [FFF18]): Position({'amount': -377, 'last_sale_price': 98.59, 'asset': Future(25376 [FFF18]), 'cost_basis': 98.59, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25760 [PAH18]): Position({'amount': 10, 'last_sale_price': 1083.35, 'asset': Future(25760 [PAH18]), 'cost_basis': 1083.35, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25366 [BZH18]): Position({'amount': 16, 'last_sale_price': 67.84, 'asset': Future(25366 [BZH18]), 'cost_basis': 67.84, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25303 [CLG18]): Position({'amount': 17, 'last_sale_price': 61.63, 'asset': Future(25303 [CLG18]), 'cost_basis': 61.63, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25737 [BPH18]): Position({'amount': 31, 'last_sale_price': 1.354, 'asset': Future(25737 [BPH18]), 'cost_basis': 1.354, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25354 [HOG18]): Position({'amount': 11, 'last_sale_price': 2.088, 'asset': Future(25354 [HOG18]), 'cost_basis': 2.088, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25789 [TUH18]): Position({'amount': -144, 'last_sale_price': 106.968, 'asset': Future(25789 [TUH18]), 'cost_basis': 106.968, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')}), Future(25711 [MDH18]): Position({'amount': 13, 'last_sale_price': 1924.4, 'asset': Future(25711 [MDH18]), 'cost_basis': 1924.4, 'last_sale_date': Timestamp('2018-01-03 21:00:00+0000', tz='UTC')})}
# Future(25376 [FFF18]) -15.407873316
# Future(25760 [PAH18]) 0.108911352417
# Future(25737 [BPH18]) 0.261757827933
# Future(25354 [HOG18]) 0.0954633497005
# Future(25303 [CLG18]) 0.104874245607
# Future(25708 [ESH18]) 0.338715798295
# Future(25710 [YMH18]) 0.348936155009
# Future(25711 [MDH18]) 0.249608205723
# Future(25715 [NQH18]) 0.210224030162
# Future(25366 [BZH18]) 0.108351251103
# Future(25719 [EDH18]) -11.3059568907
# Future(25687 [NKH18]) 0.17661098733
# Future(25788 [FVH18]) -0.997508591507
# Future(25789 [TUH18]) -3.06326989698
# portfolio:
# Portfolio({'portfolio_value': 10051752.877, 'pnl': 51752.87700000033, 'positions': {Future(25376 [FFF18]): Position({'amount': -377, 'last_sale_price': 98.587, 'asset': Future(25376 [FFF18]), 'cost_basis': 98.59, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25760 [PAH18]): Position({'amount': 10, 'last_sale_price': 1094.75, 'asset': Future(25760 [PAH18]), 'cost_basis': 1083.35, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25737 [BPH18]): Position({'amount': 31, 'last_sale_price': 1.358, 'asset': Future(25737 [BPH18]), 'cost_basis': 1.354, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25354 [HOG18]): Position({'amount': 11, 'last_sale_price': 2.077, 'asset': Future(25354 [HOG18]), 'cost_basis': 2.088, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25687 [NKH18]): Position({'amount': 15, 'last_sale_price': 23670.0, 'asset': Future(25687 [NKH18]), 'cost_basis': 23670.0, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25708 [ESH18]): Position({'amount': 25, 'last_sale_price': 2723.75, 'asset': Future(25708 [ESH18]), 'cost_basis': 2723.75, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25710 [YMH18]): Position({'amount': 28, 'last_sale_price': 25053.0, 'asset': Future(25710 [YMH18]), 'cost_basis': 25053.0, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25711 [MDH18]): Position({'amount': 13, 'last_sale_price': 1930.0, 'asset': Future(25711 [MDH18]), 'cost_basis': 1924.4, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25715 [NQH18]): Position({'amount': 16, 'last_sale_price': 6603.5, 'asset': Future(25715 [NQH18]), 'cost_basis': 6603.5, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25366 [BZH18]): Position({'amount': 16, 'last_sale_price': 68.07000000000001, 'asset': Future(25366 [BZH18]), 'cost_basis': 67.84, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25303 [CLG18]): Position({'amount': 17, 'last_sale_price': 62.01, 'asset': Future(25303 [CLG18]), 'cost_basis': 61.63, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25789 [TUH18]): Position({'amount': -144, 'last_sale_price': 106.914, 'asset': Future(25789 [TUH18]), 'cost_basis': 106.968, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')})}, 'starting_cash': 10000000.0, 'cash_flow': 51752.87700000068, 'cash': 10051752.877, 'returns': 0.005175287699999975, 'start_date': Timestamp('2018-01-02 00:00:00+0000', tz='UTC', offset='C'), 'positions_value': 0.0, 'positions_exposure': -165529150.433})
# positions:
# {Future(25376 [FFF18]): Position({'amount': -377, 'last_sale_price': 98.587, 'asset': Future(25376 [FFF18]), 'cost_basis': 98.59, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25760 [PAH18]): Position({'amount': 10, 'last_sale_price': 1094.75, 'asset': Future(25760 [PAH18]), 'cost_basis': 1083.35, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25737 [BPH18]): Position({'amount': 31, 'last_sale_price': 1.358, 'asset': Future(25737 [BPH18]), 'cost_basis': 1.354, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25354 [HOG18]): Position({'amount': 11, 'last_sale_price': 2.077, 'asset': Future(25354 [HOG18]), 'cost_basis': 2.088, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25687 [NKH18]): Position({'amount': 15, 'last_sale_price': 23670.0, 'asset': Future(25687 [NKH18]), 'cost_basis': 23670.0, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25708 [ESH18]): Position({'amount': 25, 'last_sale_price': 2723.75, 'asset': Future(25708 [ESH18]), 'cost_basis': 2723.75, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25710 [YMH18]): Position({'amount': 28, 'last_sale_price': 25053.0, 'asset': Future(25710 [YMH18]), 'cost_basis': 25053.0, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25711 [MDH18]): Position({'amount': 13, 'last_sale_price': 1930.0, 'asset': Future(25711 [MDH18]), 'cost_basis': 1924.4, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25715 [NQH18]): Position({'amount': 16, 'last_sale_price': 6603.5, 'asset': Future(25715 [NQH18]), 'cost_basis': 6603.5, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25366 [BZH18]): Position({'amount': 16, 'last_sale_price': 68.07000000000001, 'asset': Future(25366 [BZH18]), 'cost_basis': 67.84, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25303 [CLG18]): Position({'amount': 17, 'last_sale_price': 62.01, 'asset': Future(25303 [CLG18]), 'cost_basis': 61.63, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')}), Future(25789 [TUH18]): Position({'amount': -144, 'last_sale_price': 106.914, 'asset': Future(25789 [TUH18]), 'cost_basis': 106.968, 'last_sale_date': Timestamp('2018-01-04 21:00:00+0000', tz='UTC')})}

# %%
import pandas as pd
df = pd.read_pickle('quick.pickle')

# %%
df.tail()
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2018-01-19 21:00:00+00:00         0.134987                 0.070017 -0.177241
# 2018-01-22 21:00:00+00:00         0.134264                 0.084399 -0.179532
# 2018-01-23 21:00:00+00:00         0.132010                 0.083792 -0.261486
# 2018-01-24 21:00:00+00:00         0.131524                 0.098436  0.226900
# 2018-01-25 21:00:00+00:00         0.130599                 0.096673  0.146619
#
#                            benchmark_period_return  benchmark_volatility  \
# 2018-01-19 21:00:00+00:00                 0.050776              0.064129
# 2018-01-22 21:00:00+00:00                 0.059320              0.064265
# 2018-01-23 21:00:00+00:00                 0.061568              0.062473
# 2018-01-24 21:00:00+00:00                 0.061155              0.062815
# 2018-01-25 21:00:00+00:00                 0.061605              0.062133
#
#                                beta  capital_used   ending_cash  \
# 2018-01-19 21:00:00+00:00  1.557199     99606.900  1.070017e+07
# 2018-01-22 21:00:00+00:00  1.585033    143824.100  1.084399e+07
# 2018-01-23 21:00:00+00:00  1.612821     -6075.100  1.083792e+07
# 2018-01-24 21:00:00+00:00  1.347099    146435.500  1.098436e+07
# 2018-01-25 21:00:00+00:00  1.386082    -17629.035  1.096673e+07
#
#                            ending_exposure  ending_value  \
# 2018-01-19 21:00:00+00:00    -3.084928e+08           0.0
# 2018-01-22 21:00:00+00:00    -3.069634e+08           0.0
# 2018-01-23 21:00:00+00:00    -4.636086e+08           0.0
# 2018-01-24 21:00:00+00:00    -4.631705e+08           0.0
# 2018-01-25 21:00:00+00:00    -4.610566e+08           0.0
#
#                                    ...            short_exposure  short_value  \
# 2018-01-19 21:00:00+00:00          ...             -3.337968e+08          0.0
# 2018-01-22 21:00:00+00:00          ...             -3.343655e+08          0.0
# 2018-01-23 21:00:00+00:00          ...             -4.912101e+08          0.0
# 2018-01-24 21:00:00+00:00          ...             -4.911847e+08          0.0
# 2018-01-25 21:00:00+00:00          ...             -4.912213e+08          0.0
#
#                            shorts_count    sortino  starting_cash  \
# 2018-01-19 21:00:00+00:00            12  33.988795   1.060056e+07
# 2018-01-22 21:00:00+00:00            12  39.199761   1.070017e+07
# 2018-01-23 21:00:00+00:00            13  37.535740   1.084399e+07
# 2018-01-24 21:00:00+00:00            13  42.394092   1.083792e+07
# 2018-01-25 21:00:00+00:00            13  39.784051   1.098436e+07
#
#                            starting_exposure  starting_value  trading_days  \
# 2018-01-19 21:00:00+00:00      -3.083842e+08             0.0            13
# 2018-01-22 21:00:00+00:00      -3.084928e+08             0.0            14
# 2018-01-23 21:00:00+00:00      -3.069634e+08             0.0            15
# 2018-01-24 21:00:00+00:00      -4.636086e+08             0.0            16
# 2018-01-25 21:00:00+00:00      -4.631705e+08             0.0            17
#
#                                                                 transactions  \
# 2018-01-19 21:00:00+00:00  [{'price': 93.031, 'sid': Future(25743 [I3H18]...
# 2018-01-22 21:00:00+00:00  [{'price': 63.57, 'sid': Future(25506 [CLH18])...
# 2018-01-23 21:00:00+00:00  [{'price': 98.58, 'sid': Future(25582 [FFG18])...
# 2018-01-24 21:00:00+00:00  [{'price': 65.61, 'sid': Future(25506 [CLH18])...
# 2018-01-25 21:00:00+00:00  [{'price': 1362.9, 'sid': Future(25515 [GCG18]...
#
#                           treasury_period_return
# 2018-01-19 21:00:00+00:00                    0.0
# 2018-01-22 21:00:00+00:00                    0.0
# 2018-01-23 21:00:00+00:00                    0.0
# 2018-01-24 21:00:00+00:00                    0.0
# 2018-01-25 21:00:00+00:00                    0.0
#
# [5 rows x 37 columns]

# %%
transactions = df['transactions']
positions = df['positions']

# %%
transactions[1]
# Out:
# [{'amount': -377,
#   'commission': None,
#   'dt': Timestamp('2018-01-03 21:00:00+0000', tz='UTC'),
#   'order_id': 'e6599b4e58c94cd0947086b106755955',
#   'price': 98.59,
#   'sid': Future(25376 [FFF18])},
#  {'amount': 31,
#   'commission': None,
#   'dt': Timestamp('2018-01-03 21:00:00+0000', tz='UTC'),
#   'order_id': '860bc2ce54ea48408f6b85439eea3cea',
#   'price': 1.354,
#   'sid': Future(25737 [BPH18])},
#  {'amount': 10,
#   'commission': None,
#   'dt': Timestamp('2018-01-03 21:00:00+0000', tz='UTC'),
#   'order_id': 'a5c830ddb2aa4a3a9cd5d990c666b4a7',
#   'price': 1083.35,
#   'sid': Future(25760 [PAH18])},
#  {'amount': -144,
#   'commission': None,
#   'dt': Timestamp('2018-01-03 21:00:00+0000', tz='UTC'),
#   'order_id': 'b7764e62e6d249fd89a16fdece216586',
#   'price': 106.968,
#   'sid': Future(25789 [TUH18])},
#  {'amount': 13,
#   'commission': None,
#   'dt': Timestamp('2018-01-03 21:00:00+0000', tz='UTC'),
#   'order_id': '922b946408624a56a77b044540571dac',
#   'price': 1924.4,
#   'sid': Future(25711 [MDH18])}]

# %%
positions[1]
# Out:
# [{'amount': -377,
#   'cost_basis': 98.59,
#   'last_sale_price': 98.59,
#   'sid': Future(25376 [FFF18])},
#  {'amount': 31,
#   'cost_basis': 1.354,
#   'last_sale_price': 1.354,
#   'sid': Future(25737 [BPH18])},
#  {'amount': 10,
#   'cost_basis': 1083.35,
#   'last_sale_price': 1083.35,
#   'sid': Future(25760 [PAH18])},
#  {'amount': -144,
#   'cost_basis': 106.968,
#   'last_sale_price': 106.968,
#   'sid': Future(25789 [TUH18])},
#  {'amount': 13,
#   'cost_basis': 1924.4,
#   'last_sale_price': 1924.4,
#   'sid': Future(25711 [MDH18])}]
