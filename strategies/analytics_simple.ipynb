# %%
import pandas as pd
import numpy as np
import pyfolio as pf

# %%
results = pd.read_pickle('strategy_1_1.pickle')
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)

# %%
pf.create_simple_tear_sheet(returns, positions=positions, transactions=transactions, benchmark_rets=None)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-10-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>22</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>5.4%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>10.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.3%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.46</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.41</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-13.2%</td>
#     </tr>
#     <tr>
# ...
