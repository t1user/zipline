# %%
import pandas as pd
import numpy as np
import pyfolio as pf
from extract_returns import extract_returns

# %%
results = pd.read_pickle('results_strategy_1a_2013-2018.pickle')
returns, positions, transactions = extract_returns(results)
benchmark = (results['benchmark_period_return'] + 1).pct_change()

# %%
pf.create_simple_tear_sheet(returns, positions=positions, transactions=transactions, benchmark_rets=benchmark)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2013-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-10-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>70</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>14.9%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>124.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.71</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-29.1%</td>
#     </tr>
#     <tr>
# ...
